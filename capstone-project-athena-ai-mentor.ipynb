# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/agents-intensive-capstone-project/Hackathon dataset.txt

# %% [markdown]
#  # **POWERING UP ATHENA: Essential Package Installation**
#
# This cell equips your environment with cutting-edge AI tools:
# • **google-adk**: Google's Agent Development Kit for building intelligent agents
# • **ipywidgets**: Interactive UI components for engaging user experiences
# • **plotly**: Beautiful, interactive visualizations for data storytelling
#
# *Building the foundation for your intelligent research assistant...*

# %%
# Cell 1: Install required packages
# !pip install google-adk kaggle-secrets ipywidgets plotly

print("✅ Required packages installed successfully!")
# Out:
# Requirement already satisfied: google-adk in /usr/local/lib/python3.11/dist-packages (1.18.0)
# ERROR: Could not find a version that satisfies the requirement kaggle-secrets (from versions: none)
# ERROR: No matching distribution found for kaggle-secrets
# ✅ Required packages installed successfully!

# %% [markdown]
# # **INITIALIZING INTELLIGENCE: Library Import & Setup**
#
# Importing the complete toolkit for Athena's brain:
# • **Core AI Framework**: Google ADK agents and Gemini models
# • **Interactive Interface**: IPython display and widgets
# • **Secure Authentication**: Kaggle secrets management
# • **Advanced Tools**: Google Search integration for real-time research
#
# *Assembling the components of your digital research companion...*

# %%
# Cell 2: Import libraries and setup authentication
import os
import asyncio
from kaggle_secrets import UserSecretsClient
from IPython.display import display, HTML, Markdown
import ipywidgets as widgets
from google.adk.agents import Agent
from google.adk.models.google_llm import Gemini
from google.adk.runners import InMemoryRunner
from google.adk.tools import google_search
from google.genai import types
from jupyter_server.serverapp import list_running_servers

print("📚 All required libraries imported successfully!")
# Out:
# 📚 All required libraries imported successfully!

# %% [markdown]
# # **SECURE HANDHAKE: Gemini API Authentication**
#
# This cell establishes a secure connection to Google's powerful AI models:
# • **Encrypted Key Management**: Secure API key retrieval from Kaggle secrets
# • **Environment Configuration**: Seamless integration with Gemini services
# • **Visual Status Indicators**: Clear success/error feedback with beautiful styling
#
# *Establishing secure communication with advanced AI capabilities...*

# %%
# Cell 3: Setup Google API Key with enhanced styling
def setup_authentication():
    try:
        GOOGLE_API_KEY = UserSecretsClient().get_secret("GOOGLE_API_KEY")
        os.environ["GOOGLE_API_KEY"] = GOOGLE_API_KEY
        
        success_html = """
        <div style="padding: 15px; border: 2px solid #4CAF50; border-radius: 8px; background-color: #f0f9f0; margin: 20px 0;">
            <div style="font-family: sans-serif; color: #333;">
                <strong style="color: #2E7D32;">✅ Authentication Successful!</strong>
                <p style="margin: 10px 0 0 0; color: #555;">Gemini API key has been securely configured.</p>
            </div>
        </div>
        """
        display(HTML(success_html))
        return True
        
    except Exception as e:
        error_html = f"""
        <div style="padding: 15px; border: 2px solid #f44336; border-radius: 8px; background-color: #ffebee; margin: 20px 0;">
            <div style="font-family: sans-serif; color: #333;">
                <strong style="color: #C62828;">🔑 Authentication Error</strong>
                <p style="margin: 10px 0 0 0; color: #555;">
                    Please make sure you have added 'GOOGLE_API_KEY' to your Kaggle secrets.<br>
                    <strong>Error Details:</strong> {e}
                </p>
            </div>
        </div>
        """
        display(HTML(error_html))
        return False

# Run authentication
auth_success = setup_authentication()
# Out:
#         <div style="padding: 15px; border: 2px solid #4CAF50; border-radius: 8px; background-color: #f0f9f0; margin: 20px 0;">
#             <div style="font-family: sans-serif; color: #333;">
#                 <strong style="color: #2E7D32;">✅ Authentication Successful!</strong>
#                 <p style="margin: 10px 0 0 0; color: #555;">Gemini API key has been securely configured.</p>
#             </div>
#         </div>

# %% [markdown]
# # **BIRTH OF ATHENA: Intelligent Agent Creation**
#
# Creating your personal research assistant with:
# • **Advanced Retry Logic**: Smart error recovery with exponential backoff
# • **Gemini 2.5 Flash Lite**: State-of-the-art language model
# • **Research-Optimized Design**: Specialized for comprehensive analysis
# • **Google Search Integration**: Real-time information access
#
# *Bringing your intelligent research companion to life...*

# %%
# Cell 4: Configure retry settings and create Athena Agent
retry_config = types.HttpRetryOptions(
    attempts=5,
    exp_base=7,
    initial_delay=1,
    http_status_codes=[429, 500, 503, 504]
)

# Create Athena Agent
athena_agent = Agent(
    name="Athena_Research_Assistant",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    description="An intelligent research assistant that provides detailed, well-researched answers using Google Search.",
    instruction="""
    You are Athena, an advanced research assistant. Your capabilities include:
    
    🔍 **Research & Analysis**: Use Google Search to find current, accurate information
    📚 **Comprehensive Answers**: Provide detailed, well-structured responses
    💡 **Critical Thinking**: Analyze information from multiple perspectives
    🎯 **Problem Solving**: Break down complex questions into manageable parts
    📊 **Structured Output**: Organize information clearly with headings and bullet points
    
    Always:
    - Verify information using Google Search when needed
    - Cite sources when available
    - Provide balanced perspectives on controversial topics
    - Break down complex concepts into understandable parts
    - Offer practical applications and next steps
    """,
    tools=[google_search],
)

display(HTML("""
<div style="padding: 15px; border: 2px solid #2196F3; border-radius: 8px; background-color: #e3f2fd; margin: 20px 0;">
    <div style="font-family: sans-serif; color: #333;">
        <strong style="color: #1976D2;">🤖 Athena Agent Created Successfully!</strong>
        <p style="margin: 10px 0 0 0; color: #555;">
            Your intelligent research assistant is ready to help with comprehensive, well-researched answers.
        </p>
    </div>
</div>
"""))
# Out:
# <div style="padding: 15px; border: 2px solid #2196F3; border-radius: 8px; background-color: #e3f2fd; margin: 20px 0;">
#     <div style="font-family: sans-serif; color: #333;">
#         <strong style="color: #1976D2;">🤖 Athena Agent Created Successfully!</strong>
#         <p style="margin: 10px 0 0 0; color: #555;">
#             Your intelligent research assistant is ready to help with comprehensive, well-researched answers.
#         </p>
#     </div>
# </div>

# %% [markdown]
# # **ENGINE START: Agent Execution System**
#
# Launching Athena's operational core:
# • **In-Memory Processing**: High-speed query execution
# • **Real-time Response**: Instant research capabilities
# • **Session Management**: Continuous conversation context
# • **Tool Integration**: Seamless search functionality
#
# *Powering up Athena's response engine for instant intelligence...*

# %%
# Cell 5: Initialize the runner
runner = InMemoryRunner(agent=athena_agent)

display(HTML("""
<div style="padding: 15px; border: 2px solid #9C27B0; border-radius: 8px; background-color: #f3e5f5; margin: 20px 0;">
    <div style="font-family: sans-serif; color: #333;">
        <strong style="color: #7B1FA2;">🚀 Runner Initialized!</strong>
        <p style="margin: 10px 0 0 0; color: #555;">
            Athena is now ready to process your queries with enhanced capabilities.
        </p>
    </div>
</div>
"""))
# Out:
# <div style="padding: 15px; border: 2px solid #9C27B0; border-radius: 8px; background-color: #f3e5f5; margin: 20px 0;">
#     <div style="font-family: sans-serif; color: #333;">
#         <strong style="color: #7B1FA2;">🚀 Runner Initialized!</strong>
#         <p style="margin: 10px 0 0 0; color: #555;">
#             Athena is now ready to process your queries with enhanced capabilities.
#         </p>
#     </div>
# </div>

# %% [markdown]
# # **CONVERSATION PORTAL: Interactive Chat Experience**
#
# Building a beautiful interface for seamless interaction:
# • **Modern Gradient Design**: Visually appealing chat environment
# • **Real-time Typing Indicators**: Live feedback during processing
# • **Intelligent Message Formatting**: Clear distinction between user and AI
# • **One-Click Actions**: Quick query submission and history management
#
# *Creating your gateway to intelligent conversations with Athena...*

# %%
# Cell 6: Create an ULTRA-ATTRACTIVE chat interface
class AthenaChatInterface:
    def __init__(self, runner):
        self.runner = runner
        self.chat_history = []
        self.message_count = 0
        self.setup_interface()
    
    def setup_interface(self):
        # Enhanced Header with animated gradient
        header_html = """
        <div style="background: linear-gradient(135deg, 
                    #667eea 0%, #764ba2 25%, #f093fb 50%, #f5576c 75%, #4facfe 100%);
                    background-size: 400% 400%;
                    animation: gradientShift 15s ease infinite;
                    padding: 25px; border-radius: 15px; color: white; text-align: center;
                    margin-bottom: 25px; box-shadow: 0 8px 32px rgba(0,0,0,0.2);
                    border: 1px solid rgba(255,255,255,0.2);">
            <style>
                @keyframes gradientShift {
                    0% { background-position: 0% 50% }
                    50% { background-position: 100% 50% }
                    100% { background-position: 0% 50% }
                }
                @keyframes fadeIn {
                    from { opacity: 0; transform: translateY(10px); }
                    to { opacity: 1; transform: translateY(0); }
                }
                .message-animation {
                    animation: fadeIn 0.5s ease-out;
                }
                .typing-dots {
                    display: inline-block;
                }
                .typing-dots::after {
                    content: '...';
                    animation: typing 1.5s infinite;
                }
                @keyframes typing {
                    0%, 20% { content: '.'; }
                    40% { content: '..'; }
                    60%, 100% { content: '...'; }
                }
            </style>
            <h1 style="margin: 0; font-family: 'Segoe UI', sans-serif; font-size: 2.5em; 
                       text-shadow: 2px 2px 4px rgba(0,0,0,0.3);">🏛️ Athena AI Mentor</h1>
            <p style="margin: 8px 0 0 0; opacity: 0.95; font-size: 1.1em; font-weight: 300;">
                Your Intelligent Learning & Career Companion
            </p>
            <div style="margin-top: 15px; display: flex; justify-content: center; gap: 15px; flex-wrap: wrap;">
                <span style="background: rgba(255,255,255,0.2); padding: 5px 12px; border-radius: 20px; 
                            font-size: 0.9em; backdrop-filter: blur(10px);">🤖 AI-Powered</span>
                <span style="background: rgba(255,255,255,0.2); padding: 5px 12px; border-radius: 20px; 
                            font-size: 0.9em; backdrop-filter: blur(10px);">🔍 Real-time Research</span>
                <span style="background: rgba(255,255,255,0.2); padding: 5px 12px; border-radius: 20px; 
                            font-size: 0.9em; backdrop-filter: blur(10px);">🎯 Personalized Guidance</span>
            </div>
        </div>
        """
        display(HTML(header_html))
        
        # Stats Dashboard
        stats_html = """
        <div style="background: linear-gradient(135deg, #f5f7fa 0%, #c3cfe2 100%); 
                    padding: 15px; border-radius: 12px; margin: 20px 0; 
                    border: 1px solid #e1e8ed; box-shadow: 0 4px 15px rgba(0,0,0,0.1);">
            <div style="display: flex; justify-content: space-around; text-align: center; flex-wrap: wrap;">
                <div style="padding: 10px;">
                    <div style="font-size: 1.8em; font-weight: bold; color: #667eea;">0</div>
                    <div style="font-size: 0.9em; color: #666;">Messages</div>
                </div>
                <div style="padding: 10px;">
                    <div style="font-size: 1.8em; font-weight: bold; color: #764ba2;">🎯</div>
                    <div style="font-size: 0.9em; color: #666;">Active</div>
                </div>
                <div style="padding: 10px;">
                    <div style="font-size: 1.8em; font-weight: bold; color: #f093fb;">🚀</div>
                    <div style="font-size: 0.9em; color: #666;">Ready</div>
                </div>
            </div>
        </div>
        """
        display(HTML(stats_html))
        
        # Enhanced Chat output area with glass morphism effect
        self.output = widgets.Output(layout={
            'border': '1px solid rgba(255,255,255,0.2)',
            'height': '500px', 
            'overflow_y': 'auto',
            'padding': '15px',
            'background': 'linear-gradient(135deg, rgba(255,255,255,0.9) 0%, rgba(245,247,250,0.9) 100%)',
            'border_radius': '15px',
            'box_shadow': '0 8px 32px rgba(0,0,0,0.1)',
            'backdrop_filter': 'blur(10px)'
        })
        
        # Enhanced Input area
        self.input_text = widgets.Textarea(
            value='',
            placeholder='💭 Ask your AI mentor anything about career guidance, learning strategies, or project help... (Press Shift+Enter to send)',
            layout=widgets.Layout(
                width='100%', 
                height='100px',
                border='2px solid #e1e8ed',
                border_radius='12px',
                padding='15px',
                font_size='14px',
                background='rgba(255,255,255,0.8)'
            )
        )
        
        # Enhanced Buttons with hover effects
        self.send_button = widgets.Button(
            description="🚀 Send to Mentor",
            button_style='success',
            icon='rocket',
            layout=widgets.Layout(
                width='180px', 
                height='45px',
                margin='5px',
                border_radius='25px',
                font_weight='bold'
            ),
            style={'button_color': '#667eea', 'font_weight': 'bold'}
        )
        
        self.clear_button = widgets.Button(
            description="🗑️ Clear Chat",
            button_style='warning',
            icon='trash',
            layout=widgets.Layout(
                width='150px', 
                height='45px',
                margin='5px',
                border_radius='25px'
            )
        )
        
        self.export_button = widgets.Button(
            description="📥 Export Chat",
            button_style='info',
            icon='download',
            layout=widgets.Layout(
                width='150px', 
                height='45px',
                margin='5px',
                border_radius='25px'
            )
        )
        
        # Button events
        self.send_button.on_click(self.send_message)
        self.clear_button.on_click(self.clear_chat)
        self.export_button.on_click(self.export_chat)
        self.input_text.observe(self.handle_enter, names='value')
        
        # Display widgets with better layout
        buttons_layout = widgets.HBox([
            self.send_button, 
            self.clear_button, 
            self.export_button
        ], layout=widgets.Layout(
            justify_content='center',
            margin='15px 0'
        ))
        
        display(self.output)
        display(self.input_text)
        display(buttons_layout)
        
        # Welcome message
        self.add_welcome_message()
    
    def add_welcome_message(self):
        welcome_msg = """
        <div class="message-animation" style="
            background: linear-gradient(135deg, #667eea 0%, #764ba2 100%);
            color: white; padding: 20px; margin: 15px 0; 
            border-radius: 20px; border-left: 5px solid #4facfe;
            box-shadow: 0 4px 15px rgba(102, 126, 234, 0.3);
            position: relative;
        ">
            <div style="position: absolute; top: 10px; right: 15px; font-size: 1.5em;">🏛️</div>
            <strong style="font-size: 1.1em;">Athena AI Mentor:</strong> 
            <div style="margin-top: 10px; font-size: 1.05em;">
                Welcome! I'm your personal AI mentor, here to guide your learning and career journey.
            </div>
            <div style="margin-top: 15px; display: grid; grid-template-columns: repeat(auto-fit, minmax(200px, 1fr)); gap: 10px;">
                <div style="background: rgba(255,255,255,0.2); padding: 8px; border-radius: 8px;">
                    <span style="font-size: 1.2em;">🎯</span> Career Guidance
                </div>
                <div style="background: rgba(255,255,255,0.2); padding: 8px; border-radius: 8px;">
                    <span style="font-size: 1.2em;">📚</span> Learning Support
                </div>
                <div style="background: rgba(255,255,255,0.2); padding: 8px; border-radius: 8px;">
                    <span style="font-size: 1.2em;">💡</span> Project Mentoring
                </div>
                <div style="background: rgba(255,255,255,0.2); padding: 8px; border-radius: 8px;">
                    <span style="font-size: 1.2em;">🚀</span> Skill Development
                </div>
            </div>
            <div style="margin-top: 15px; padding: 12px; background: rgba(255,255,255,0.1); 
                        border-radius: 10px; border-left: 3px solid #4facfe;">
                <strong>💡 Pro Tip:</strong> Be specific about your goals for the most personalized advice!
            </div>
        </div>
        """
        with self.output:
            display(HTML(welcome_msg))
    
    def update_stats(self):
        """Update the message statistics"""
        stats_html = f"""
        <script>
            document.querySelector('[style*="f5f7fa"]').innerHTML = `
                <div style="display: flex; justify-content: space-around; text-align: center; flex-wrap: wrap;">
                    <div style="padding: 10px;">
                        <div style="font-size: 1.8em; font-weight: bold; color: #667eea;">{self.message_count}</div>
                        <div style="font-size: 0.9em; color: #666;">Messages</div>
                    </div>
                    <div style="padding: 10px;">
                        <div style="font-size: 1.8em; font-weight: bold; color: #764ba2;">🎯</div>
                        <div style="font-size: 0.9em; color: #666;">Active</div>
                    </div>
                    <div style="padding: 10px;">
                        <div style="font-size: 1.8em; font-weight: bold; color: #f093fb;">🚀</div>
                        <div style="font-size: 0.9em; color: #666;">Ready</div>
                    </div>
                </div>
            `;
        </script>
        """
        display(HTML(stats_html))
    
    def handle_enter(self, change):
        if change['new'] and change['new'].endswith('\n\n'):
            self.input_text.value = change['new'].rstrip('\n')
            self.send_message(None)
    
    async def process_query(self, query):
        try:
            response = await self.runner.run_debug(query)
            return response
        except Exception as e:
            return f"❌ I encountered an error while processing your request: {str(e)}\n\nPlease try again or rephrase your question."
    
    def send_message(self, b):
        query = self.input_text.value.strip()
        if not query:
            return
        
        self.message_count += 1
        self.update_stats()
            
        # Add user message to chat with enhanced styling
        user_html = f"""
        <div class="message-animation" style="
            background: linear-gradient(135deg, #4facfe 0%, #00f2fe 100%);
            color: white; padding: 15px 20px; margin: 15px 0; 
            border-radius: 20px 20px 5px 20px; max-width: 75%; 
            float: right; clear: both; box-shadow: 0 4px 15px rgba(79, 172, 254, 0.3);
            position: relative;
        ">
            <div style="position: absolute; top: -8px; right: -8px; background: #667eea; 
                        border-radius: 50%; width: 25px; height: 25px; display: flex; 
                        align-items: center; justify-content: center; font-size: 0.8em;">
                👤
            </div>
            <strong>You:</strong><br>
            <div style="margin-top: 5px; font-size: 1.05em;">{query}</div>
            <div style="font-size: 0.8em; opacity: 0.8; text-align: right; margin-top: 8px;">
                {self.get_current_time()}
            </div>
        </div>
        """
        
        with self.output:
            display(HTML(user_html))
        
        # Clear input
        self.input_text.value = ''
        
        # Show enhanced typing indicator
        thinking_html = """
        <div class="message-animation" style="
            background: linear-gradient(135deg, #a8edea 0%, #fed6e3 100%);
            padding: 15px 20px; margin: 15px 0; border-radius: 20px 20px 20px 5px; 
            max-width: 60%; float: left; clear: both; box-shadow: 0 4px 15px rgba(168, 237, 234, 0.3);
            border-left: 4px solid #667eea;
        ">
            <strong>🏛️ Athena:</strong> 
            <span class="typing-dots" style="color: #666; font-style: italic;">
                Analyzing your query and researching
            </span>
            <div style="margin-top: 8px; font-size: 0.8em; color: #666;">
                🔍 Searching knowledge • 💡 Processing insights • 🎯 Preparing guidance
            </div>
        </div>
        """
        
        with self.output:
            thinking_display = display(HTML(thinking_html), display_id=True)
        
        # Process query
        async def get_response():
            response = await self.process_query(query)
            
            # Enhanced response formatting
            response_html = f"""
            <div class="message-animation" style="
                background: linear-gradient(135deg, #667eea 0%, #764ba2 100%);
                color: white; padding: 20px; margin: 15px 0; 
                border-radius: 20px 20px 20px 5px; max-width: 85%; 
                float: left; clear: both; box-shadow: 0 6px 20px rgba(102, 126, 234, 0.4);
                position: relative; border-left: 5px solid #4facfe;
            ">
                <div style="position: absolute; top: -10px; left: -10px; background: #ff6b6b; 
                            border-radius: 50%; width: 30px; height: 30px; display: flex; 
                            align-items: center; justify-content: center; font-size: 0.9em;
                            box-shadow: 0 2px 8px rgba(255, 107, 107, 0.4);">
                    🏛️
                </div>
                <strong style="font-size: 1.1em;">Athena AI Mentor:</strong><br>
                <div style="margin-top: 10px; font-size: 1.05em; line-height: 1.5;">
                    {response}
                </div>
                <div style="margin-top: 15px; padding-top: 10px; border-top: 1px solid rgba(255,255,255,0.3); 
                            font-size: 0.8em; opacity: 0.8; display: flex; justify-content: space-between;">
                    <span>✅ Response Generated</span>
                    <span>{self.get_current_time()}</span>
                </div>
            </div>
            <div style="clear: both;"></div>
            """
            
            # Update display
            thinking_display.update(HTML(response_html))
            
            # Auto-scroll to bottom
            self.scroll_to_bottom()
        
        # Run async function
        asyncio.run(get_response())
    
    def get_current_time(self):
        from datetime import datetime
        return datetime.now().strftime("%H:%M:%S")
    
    def scroll_to_bottom(self):
        """Scroll chat to bottom"""
        display(HTML("""
        <script>
            setTimeout(() => {
                const output = document.querySelector('[data-mime-type="application/vnd.jupyter.widget-view+json"]');
                if (output) {
                    output.scrollTop = output.scrollHeight;
                }
            }, 100);
        </script>
        """))
    
    def clear_chat(self, b):
        self.message_count = 0
        self.update_stats()
        self.output.clear_output()
        self.add_welcome_message()
        display(HTML("""
        <div style="background: #ff6b6b; color: white; padding: 10px; border-radius: 8px; 
                    margin: 10px 0; text-align: center; font-weight: bold;">
            🗑️ Chat history cleared
        </div>
        """))
    
    def export_chat(self, b):
        """Export chat history (placeholder functionality)"""
        display(HTML("""
        <div style="background: #4ecdc4; color: white; padding: 12px; border-radius: 8px; 
                    margin: 10px 0; text-align: center; font-weight: bold;">
            📥 Export feature coming soon! Your chat history will be downloadable in the next update.
        </div>
        """))

# Initialize the enhanced chat interface
display(HTML("""
<div style="text-align: center; margin: 20px 0;">
    <div style="font-size: 1.2em; color: #667eea; font-weight: bold;">
        Initializing Enhanced AI Mentor Interface...
    </div>
    <div style="margin-top: 10px;">
        <span style="display: inline-block; width: 10px; height: 10px; background: #667eea; 
                   border-radius: 50%; margin: 0 2px; animation: pulse 1.5s infinite;"></span>
        <span style="display: inline-block; width: 10px; height: 10px; background: #764ba2; 
                   border-radius: 50%; margin: 0 2px; animation: pulse 1.5s infinite 0.2s;"></span>
        <span style="display: inline-block; width: 10px; height: 10px; background: #f093fb; 
                   border-radius: 50%; margin: 0 2px; animation: pulse 1.5s infinite 0.4s;"></span>
    </div>
</div>
"""))

chat_interface = AthenaChatInterface(runner)
# Out:
# <div style="text-align: center; margin: 20px 0;">
#     <div style="font-size: 1.2em; color: #667eea; font-weight: bold;">
#         Initializing Enhanced AI Mentor Interface...
#     </div>
#     <div style="margin-top: 10px;">
#         <span style="display: inline-block; width: 10px; height: 10px; background: #667eea;
#                    border-radius: 50%; margin: 0 2px; animation: pulse 1.5s infinite;"></span>
#         <span style="display: inline-block; width: 10px; height: 10px; background: #764ba2;
#                    border-radius: 50%; margin: 0 2px; animation: pulse 1.5s infinite 0.2s;"></span>
#         <span style="display: inline-block; width: 10px; height: 10px; background: #f093fb;
#                    border-radius: 50%; margin: 0 2px; animation: pulse 1.5s infinite 0.4s;"></span>
#     </div>
# </div>
#         <div style="background: linear-gradient(135deg,
#                     #667eea 0%, #764ba2 25%, #f093fb 50%, #f5576c 75%, #4facfe 100%);
#                     background-size: 400% 400%;
#                     animation: gradientShift 15s ease infinite;
#                     padding: 25px; border-radius: 15px; color: white; text-align: center;
#                     margin-bottom: 25px; box-shadow: 0 8px 32px rgba(0,0,0,0.2);
#                     border: 1px solid rgba(255,255,255,0.2);">
#             <style>
#                 @keyframes gradientShift {
#                     0% { background-position: 0% 50% }
#                     50% { background-position: 100% 50% }
#                     100% { background-position: 0% 50% }
#                 }
#                 @keyframes fadeIn {
#                     from { opacity: 0; transform: translateY(10px); }
#                     to { opacity: 1; transform: translateY(0); }
#                 }
#                 .message-animation {
#                     animation: fadeIn 0.5s ease-out;
#                 }
#                 .typing-dots {
#                     display: inline-block;
#                 }
#                 .typing-dots::after {
#                     content: '...';
#                     animation: typing 1.5s infinite;
#                 }
#                 @keyframes typing {
#                     0%, 20% { content: '.'; }
#                     40% { content: '..'; }
#                     60%, 100% { content: '...'; }
#                 }
#             </style>
#             <h1 style="margin: 0; font-family: 'Segoe UI', sans-serif; font-size: 2.5em;
#                        text-shadow: 2px 2px 4px rgba(0,0,0,0.3);">🏛️ Athena AI Mentor</h1>
#             <p style="margin: 8px 0 0 0; opacity: 0.95; font-size: 1.1em; font-weight: 300;">
#                 Your Intelligent Learning & Career Companion
#             </p>
#             <div style="margin-top: 15px; display: flex; justify-content: center; gap: 15px; flex-wrap: wrap;">
#                 <span style="background: rgba(255,255,255,0.2); padding: 5px 12px; border-radius: 20px;
#                             font-size: 0.9em; backdrop-filter: blur(10px);">🤖 AI-Powered</span>
#                 <span style="background: rgba(255,255,255,0.2); padding: 5px 12px; border-radius: 20px;
#                             font-size: 0.9em; backdrop-filter: blur(10px);">🔍 Real-time Research</span>
#                 <span style="background: rgba(255,255,255,0.2); padding: 5px 12px; border-radius: 20px;
#                             font-size: 0.9em; backdrop-filter: blur(10px);">🎯 Personalized Guidance</span>
#             </div>
#         </div>
#         <div style="background: linear-gradient(135deg, #f5f7fa 0%, #c3cfe2 100%);
#                     padding: 15px; border-radius: 12px; margin: 20px 0;
#                     border: 1px solid #e1e8ed; box-shadow: 0 4px 15px rgba(0,0,0,0.1);">
#             <div style="display: flex; justify-content: space-around; text-align: center; flex-wrap: wrap;">
#                 <div style="padding: 10px;">
#                     <div style="font-size: 1.8em; font-weight: bold; color: #667eea;">0</div>
#                     <div style="font-size: 0.9em; color: #666;">Messages</div>
#                 </div>
#                 <div style="padding: 10px;">
#                     <div style="font-size: 1.8em; font-weight: bold; color: #764ba2;">🎯</div>
#                     <div style="font-size: 0.9em; color: #666;">Active</div>
#                 </div>
#                 <div style="padding: 10px;">
#                     <div style="font-size: 1.8em; font-weight: bold; color: #f093fb;">🚀</div>
#                     <div style="font-size: 0.9em; color: #666;">Ready</div>
#                 </div>
#             </div>
#         </div>
# Output(layout=Layout(border_bottom='1px solid rgba(255,255,255,0.2)', border_left='1px solid rgba(255,255,255,…
# Textarea(value='', layout=Layout(border_bottom='2px solid #e1e8ed', border_left='2px solid #e1e8ed', border_ri…
# HBox(children=(Button(button_style='success', description='🚀 Send to Mentor', icon='rocket', layout=Layout(hei…

# %% [markdown]
# # **SMART SHORTCUTS: One-Click Research Queries**
#
# Pre-configured intelligent prompts for instant insights:
# • **Research Assistance**: Deep-dive analysis on complex topics
# • **Learning Support**: Educational explanations and study help
# • **Trend Analysis**: Current events and emerging technologies
# • **Technical Guidance**: Expert-level technical explanations
#
# *Accelerating your research journey with curated intelligence paths...*

# %%
# Cell 7: Create ULTRA-ATTRACTIVE quick action buttons for common queries
def create_quick_actions(chat_interface):
    # Enhanced Header with animated background
    quick_actions_html = """
    <div style="
        background: linear-gradient(135deg, #667eea 0%, #764ba2 25%, #f093fb 50%, #f5576c 75%, #4facfe 100%);
        background-size: 400% 400%;
        animation: gradientShift 15s ease infinite;
        padding: 25px; 
        border-radius: 20px; 
        margin: 30px 0; 
        box-shadow: 0 12px 40px rgba(102, 126, 234, 0.25);
        border: 1px solid rgba(255,255,255,0.3);
        backdrop-filter: blur(10px);
        position: relative;
        overflow: hidden;
    ">
        <div style="position: absolute; top: 0; left: 0; right: 0; bottom: 0; 
                    background: rgba(255,255,255,0.1); backdrop-filter: blur(5px);"></div>
        <div style="position: relative; z-index: 2; text-align: center; color: white;">
            <h2 style="margin: 0 0 10px 0; font-family: 'Segoe UI', sans-serif; 
                      font-size: 2.2em; text-shadow: 2px 2px 8px rgba(0,0,0,0.3);">
                🚀 Quick Mentor Actions
            </h2>
            <p style="margin: 0; font-size: 1.2em; opacity: 0.95; font-weight: 300;
                     text-shadow: 1px 1px 4px rgba(0,0,0,0.2);">
                Instant guidance for your learning and career journey
            </p>
        </div>
        <div style="position: absolute; bottom: 10px; right: 20px; font-size: 3em; 
                   opacity: 0.1; z-index: 1;">⚡</div>
    </div>
    
    <div style="background: linear-gradient(135deg, #f5f7fa 0%, #c3cfe2 100%); 
                padding: 20px; border-radius: 15px; margin: 20px 0;
                box-shadow: 0 6px 25px rgba(0,0,0,0.1); border: 1px solid rgba(255,255,255,0.5);">
        <div style="text-align: center; margin-bottom: 15px;">
            <h3 style="color: #667eea; margin: 0 0 10px 0; font-size: 1.4em;">
                💡 One-Click Mentor Guidance
            </h3>
            <p style="color: #666; margin: 0; font-size: 1.05em;">
                Tap any button below for instant AI-powered mentorship on common topics
            </p>
        </div>
    </div>
    """
    display(HTML(quick_actions_html))
    
    # Enhanced quick actions with mentor focus
    quick_queries = [
        {
            "emoji": "🎯",
            "title": "Career Path Guidance",
            "query": "Can you help me plan my career path in data science and artificial intelligence?",
            "color": "#667eea",
            "description": "Get personalized career roadmap"
        },
        {
            "emoji": "📚",
            "title": "Study Strategy Support",
            "query": "I need help developing effective learning strategies for machine learning and AI concepts.",
            "color": "#764ba2",
            "description": "Optimize your learning approach"
        },
        {
            "emoji": "💡",
            "title": "Project Mentoring",
            "query": "How should I approach my capstone project in AI and what are the best practices?",
            "color": "#f093fb",
            "description": "Expert project guidance"
        },
        {
            "emoji": "🚀",
            "title": "Skill Development",
            "query": "What are the most important skills I should focus on to advance in AI and data science careers?",
            "color": "#f5576c",
            "description": "Build in-demand skills"
        },
        {
            "emoji": "🔍",
            "title": "Industry Research",
            "query": "What are the latest trends and job market insights in artificial intelligence and machine learning?",
            "color": "#4facfe",
            "description": "Stay current with industry"
        },
        {
            "emoji": "📊",
            "title": "Portfolio Building",
            "query": "How can I build an impressive portfolio for data science and AI job applications?",
            "color": "#43e97b",
            "description": "Showcase your abilities"
        },
        {
            "emoji": "🎓",
            "title": "Learning Resources",
            "query": "What are the best online courses, books, and resources for learning AI and data science?",
            "color": "#ff9a9e",
            "description": "Discover top learning materials"
        },
        {
            "emoji": "💼",
            "title": "Interview Preparation",
            "query": "How should I prepare for technical interviews in data science and AI roles?",
            "color": "#a8edea",
            "description": "Ace your job interviews"
        }
    ]
    
    # Create enhanced buttons with proper styling
    buttons = []
    for action in quick_queries:
        # Create button with proper HTML description
        btn = widgets.Button(
            description=f"{action['emoji']} {action['title']}",
            tooltip=action['query'],
            layout=widgets.Layout(
                width='280px',
                height='80px',
                margin='8px',
                border_radius='15px',
                border=f'3px solid {action["color"]}40'
            )
        )
        
        # Apply proper button styling using the style attribute
        btn.style.button_color = '#ffffff'
        btn.style.font_weight = 'bold'
        btn.style.text_color = '#333333'
        
        btn.query = action['query']
        btn.emoji = action['emoji']
        btn.color = action['color']
        btn.on_click(lambda b: chat_interface.input_text.set_value(b.query))
        buttons.append(btn)
    
    # Add custom CSS for hover effects
    display(HTML(f"""
    <style>
        .quick-action-button {{
            transition: all 0.3s ease !important;
            box-shadow: 0 4px 15px rgba(0,0,0,0.1) !important;
        }}
        .quick-action-button:hover {{
            transform: translateY(-3px) !important;
            box-shadow: 0 8px 25px rgba(102, 126, 234, 0.3) !important;
        }}
        {''.join([f'''
        .button-{i} {{
            background: linear-gradient(135deg, #ffffff 0%, #f8f9fa 100%) !important;
            border: 3px solid {action['color']}40 !important;
        }}
        .button-{i}:hover {{
            background: linear-gradient(135deg, {action['color']}15 0%, {action['color']}30 100%) !important;
            border: 3px solid {action['color']}80 !important;
        }}
        ''' for i, action in enumerate(quick_queries)])}
    </style>
    """))
    
    # Apply CSS classes to buttons
    for i, btn in enumerate(buttons):
        btn.add_class(f"quick-action-button button-{i}")
    
    # Enhanced grid layout with better spacing
    grid = widgets.GridBox(
        buttons,
        layout=widgets.Layout(
            grid_template_columns="repeat(auto-fit, minmax(280px, 1fr))",
            gap="20px",
            padding="20px",
            justify_content="center",
            align_items="center"
        )
    )
    
    # Container with enhanced styling
    grid_container = widgets.VBox([
        widgets.HTML("""
        <div style="text-align: center; margin: 10px 0 20px 0;">
            <div style="display: inline-flex; align-items: center; background: rgba(102, 126, 234, 0.1); 
                       padding: 8px 16px; border-radius: 20px; color: #667eea; font-weight: 500;">
                <span style="margin-right: 8px;">🔽</span>
                Click any card below to instantly ask your mentor
            </div>
        </div>
        """),
        grid
    ], layout=widgets.Layout(
        width='100%',
        padding='10px'
    ))
    
    display(grid_container)
    
    # Add detailed descriptions for each action
    actions_details_html = """
    <div style="
        background: linear-gradient(135deg, #f8f9fa 0%, #e9ecef 100%);
        padding: 25px; 
        border-radius: 15px; 
        margin: 20px 0;
        box-shadow: 0 4px 15px rgba(0,0,0,0.05);
    ">
        <h4 style="text-align: center; color: #667eea; margin: 0 0 20px 0; font-size: 1.3em;">
            📋 Quick Actions Overview
        </h4>
        <div style="display: grid; grid-template-columns: repeat(auto-fit, minmax(300px, 1fr)); gap: 15px;">
    """
    
    for action in quick_queries:
        actions_details_html += f"""
            <div style="
                background: white; 
                padding: 15px; 
                border-radius: 10px; 
                border-left: 4px solid {action['color']};
                box-shadow: 0 2px 8px rgba(0,0,0,0.05);
            ">
                <div style="display: flex; align-items: center; gap: 10px; margin-bottom: 8px;">
                    <span style="font-size: 1.5em;">{action['emoji']}</span>
                    <strong style="color: #333; font-size: 1.1em;">{action['title']}</strong>
                </div>
                <div style="color: #666; font-size: 0.95em; line-height: 1.4;">
                    {action['description']}
                </div>
            </div>
        """
    
    actions_details_html += """
        </div>
    </div>
    """
    display(HTML(actions_details_html))
    
    # Footer with usage tips
    footer_html = """
    <div style="
        background: linear-gradient(135deg, #a8edea 0%, #fed6e3 100%);
        padding: 20px; 
        border-radius: 15px; 
        margin: 30px 0 10px 0;
        text-align: center;
        box-shadow: 0 6px 20px rgba(168, 237, 234, 0.3);
        border: 1px solid rgba(255,255,255,0.5);
    ">
        <div style="display: flex; align-items: center; justify-content: center; gap: 15px; flex-wrap: wrap;">
            <div style="display: flex; align-items: center; gap: 8px;">
                <span style="background: #667eea; color: white; border-radius: 50%; 
                           width: 25px; height: 25px; display: flex; align-items: center; 
                           justify-content: center; font-size: 0.8em;">💡</span>
                <span style="color: #666; font-weight: 500;">Quick Start</span>
            </div>
            <div style="display: flex; align-items: center; gap: 8px;">
                <span style="background: #764ba2; color: white; border-radius: 50%; 
                           width: 25px; height: 25px; display: flex; align-items: center; 
                           justify-content: center; font-size: 0.8em;">🎯</span>
                <span style="color: #666; font-weight: 500;">Focused Topics</span>
            </div>
            <div style="display: flex; align-items: center; gap: 8px;">
                <span style="background: #f5576c; color: white; border-radius: 50%; 
                           width: 25px; height: 25px; display: flex; align-items: center; 
                           justify-content: center; font-size: 0.8em;">🚀</span>
                <span style="color: #666; font-weight: 500;">Instant Results</span>
            </div>
        </div>
        <div style="margin-top: 15px; color: #666; font-size: 0.95em;">
            <strong>Pro Tip:</strong> Use these quick actions as starting points, then ask follow-up questions for personalized advice!
        </div>
    </div>
    """
    display(HTML(footer_html))

# Display loading animation before showing quick actions
display(HTML("""
<div style="text-align: center; margin: 20px 0; padding: 30px;">
    <div style="font-size: 1.3em; color: #667eea; font-weight: bold; margin-bottom: 15px;">
        🎯 Loading Mentor Quick Actions...
    </div>
    <div style="display: flex; justify-content: center; gap: 8px;">
        <div style="width: 12px; height: 12px; background: #667eea; border-radius: 50%; 
                  animation: bounce 1.4s infinite ease-in-out;"></div>
        <div style="width: 12px; height: 12px; background: #764ba2; border-radius: 50%; 
                  animation: bounce 1.4s infinite ease-in-out 0.2s;"></div>
        <div style="width: 12px; height: 12px; background: #f093fb; border-radius: 50%; 
                  animation: bounce 1.4s infinite ease-in-out 0.4s;"></div>
    </div>
    <style>
        @keyframes bounce {
            0%, 80%, 100% { transform: scale(0.8); opacity: 0.5; }
            40% { transform: scale(1.2); opacity: 1; }
        }
    </style>
</div>
"""))

create_quick_actions(chat_interface)
# Out:
# <div style="text-align: center; margin: 20px 0; padding: 30px;">
#     <div style="font-size: 1.3em; color: #667eea; font-weight: bold; margin-bottom: 15px;">
#         🎯 Loading Mentor Quick Actions...
#     </div>
#     <div style="display: flex; justify-content: center; gap: 8px;">
#         <div style="width: 12px; height: 12px; background: #667eea; border-radius: 50%;
#                   animation: bounce 1.4s infinite ease-in-out;"></div>
#         <div style="width: 12px; height: 12px; background: #764ba2; border-radius: 50%;
#                   animation: bounce 1.4s infinite ease-in-out 0.2s;"></div>
#         <div style="width: 12px; height: 12px; background: #f093fb; border-radius: 50%;
#                   animation: bounce 1.4s infinite ease-in-out 0.4s;"></div>
#     </div>
#     <style>
#         @keyframes bounce {
#             0%, 80%, 100% { transform: scale(0.8); opacity: 0.5; }
#             40% { transform: scale(1.2); opacity: 1; }
#         }
#     </style>
# </div>
#     <div style="
#         background: linear-gradient(135deg, #667eea 0%, #764ba2 25%, #f093fb 50%, #f5576c 75%, #4facfe 100%);
#         background-size: 400% 400%;
#         animation: gradientShift 15s ease infinite;
#         padding: 25px;
#         border-radius: 20px;
#         margin: 30px 0;
#         box-shadow: 0 12px 40px rgba(102, 126, 234, 0.25);
#         border: 1px solid rgba(255,255,255,0.3);
#         backdrop-filter: blur(10px);
#         position: relative;
#         overflow: hidden;
#     ">
#         <div style="position: absolute; top: 0; left: 0; right: 0; bottom: 0;
#                     background: rgba(255,255,255,0.1); backdrop-filter: blur(5px);"></div>
#         <div style="position: relative; z-index: 2; text-align: center; color: white;">
#             <h2 style="margin: 0 0 10px 0; font-family: 'Segoe UI', sans-serif;
#                       font-size: 2.2em; text-shadow: 2px 2px 8px rgba(0,0,0,0.3);">
#                 🚀 Quick Mentor Actions
#             </h2>
#             <p style="margin: 0; font-size: 1.2em; opacity: 0.95; font-weight: 300;
#                      text-shadow: 1px 1px 4px rgba(0,0,0,0.2);">
#                 Instant guidance for your learning and career journey
#             </p>
#         </div>
#         <div style="position: absolute; bottom: 10px; right: 20px; font-size: 3em;
#                    opacity: 0.1; z-index: 1;">⚡</div>
#     </div>
#
#     <div style="background: linear-gradient(135deg, #f5f7fa 0%, #c3cfe2 100%);
#                 padding: 20px; border-radius: 15px; margin: 20px 0;
#                 box-shadow: 0 6px 25px rgba(0,0,0,0.1); border: 1px solid rgba(255,255,255,0.5);">
#         <div style="text-align: center; margin-bottom: 15px;">
#             <h3 style="color: #667eea; margin: 0 0 10px 0; font-size: 1.4em;">
#                 💡 One-Click Mentor Guidance
#             </h3>
#             <p style="color: #666; margin: 0; font-size: 1.05em;">
#                 Tap any button below for instant AI-powered mentorship on common topics
#             </p>
#         </div>
#     </div>
#     <style>
#         .quick-action-button {
#             transition: all 0.3s ease !important;
#             box-shadow: 0 4px 15px rgba(0,0,0,0.1) !important;
#         }
#         .quick-action-button:hover {
#             transform: translateY(-3px) !important;
#             box-shadow: 0 8px 25px rgba(102, 126, 234, 0.3) !important;
#         }
#
#         .button-0 {
#             background: linear-gradient(135deg, #ffffff 0%, #f8f9fa 100%) !important;
#             border: 3px solid #667eea40 !important;
#         }
#         .button-0:hover {
#             background: linear-gradient(135deg, #667eea15 0%, #667eea30 100%) !important;
#             border: 3px solid #667eea80 !important;
#         }
#
#         .button-1 {
#             background: linear-gradient(135deg, #ffffff 0%, #f8f9fa 100%) !important;
#             border: 3px solid #764ba240 !important;
#         }
#         .button-1:hover {
#             background: linear-gradient(135deg, #764ba215 0%, #764ba230 100%) !important;
#             border: 3px solid #764ba280 !important;
#         }
#
#         .button-2 {
#             background: linear-gradient(135deg, #ffffff 0%, #f8f9fa 100%) !important;
#             border: 3px solid #f093fb40 !important;
#         }
#         .button-2:hover {
#             background: linear-gradient(135deg, #f093fb15 0%, #f093fb30 100%) !important;
#             border: 3px solid #f093fb80 !important;
#         }
#
#         .button-3 {
#             background: linear-gradient(135deg, #ffffff 0%, #f8f9fa 100%) !important;
#             border: 3px solid #f5576c40 !important;
#         }
#         .button-3:hover {
#             background: linear-gradient(135deg, #f5576c15 0%, #f5576c30 100%) !important;
#             border: 3px solid #f5576c80 !important;
#         }
#
#         .button-4 {
#             background: linear-gradient(135deg, #ffffff 0%, #f8f9fa 100%) !important;
#             border: 3px solid #4facfe40 !important;
#         }
#         .button-4:hover {
#             background: linear-gradient(135deg, #4facfe15 0%, #4facfe30 100%) !important;
#             border: 3px solid #4facfe80 !important;
#         }
#
#         .button-5 {
#             background: linear-gradient(135deg, #ffffff 0%, #f8f9fa 100%) !important;
#             border: 3px solid #43e97b40 !important;
#         }
#         .button-5:hover {
#             background: linear-gradient(135deg, #43e97b15 0%, #43e97b30 100%) !important;
#             border: 3px solid #43e97b80 !important;
#         }
#
#         .button-6 {
#             background: linear-gradient(135deg, #ffffff 0%, #f8f9fa 100%) !important;
#             border: 3px solid #ff9a9e40 !important;
#         }
#         .button-6:hover {
#             background: linear-gradient(135deg, #ff9a9e15 0%, #ff9a9e30 100%) !important;
#             border: 3px solid #ff9a9e80 !important;
#         }
#
#         .button-7 {
#             background: linear-gradient(135deg, #ffffff 0%, #f8f9fa 100%) !important;
#             border: 3px solid #a8edea40 !important;
#         }
#         .button-7:hover {
#             background: linear-gradient(135deg, #a8edea15 0%, #a8edea30 100%) !important;
#             border: 3px solid #a8edea80 !important;
#         }
#
#     </style>
# VBox(children=(HTML(value='\n        <div style="text-align: center; margin: 10px 0 20px 0;">\n            <di…
#     <div style="
#         background: linear-gradient(135deg, #f8f9fa 0%, #e9ecef 100%);
#         padding: 25px;
#         border-radius: 15px;
#         margin: 20px 0;
#         box-shadow: 0 4px 15px rgba(0,0,0,0.05);
#     ">
#         <h4 style="text-align: center; color: #667eea; margin: 0 0 20px 0; font-size: 1.3em;">
#             📋 Quick Actions Overview
#         </h4>
#         <div style="display: grid; grid-template-columns: repeat(auto-fit, minmax(300px, 1fr)); gap: 15px;">
#
#             <div style="
#                 background: white;
#                 padding: 15px;
#                 border-radius: 10px;
#                 border-left: 4px solid #667eea;
#                 box-shadow: 0 2px 8px rgba(0,0,0,0.05);
#             ">
#                 <div style="display: flex; align-items: center; gap: 10px; margin-bottom: 8px;">
#                     <span style="font-size: 1.5em;">🎯</span>
#                     <strong style="color: #333; font-size: 1.1em;">Career Path Guidance</strong>
#                 </div>
#                 <div style="color: #666; font-size: 0.95em; line-height: 1.4;">
#                     Get personalized career roadmap
#                 </div>
#             </div>
#
#             <div style="
#                 background: white;
#                 padding: 15px;
#                 border-radius: 10px;
#                 border-left: 4px solid #764ba2;
#                 box-shadow: 0 2px 8px rgba(0,0,0,0.05);
#             ">
#                 <div style="display: flex; align-items: center; gap: 10px; margin-bottom: 8px;">
#                     <span style="font-size: 1.5em;">📚</span>
#                     <strong style="color: #333; font-size: 1.1em;">Study Strategy Support</strong>
#                 </div>
#                 <div style="color: #666; font-size: 0.95em; line-height: 1.4;">
#                     Optimize your learning approach
#                 </div>
#             </div>
#
#             <div style="
#                 background: white;
#                 padding: 15px;
#                 border-radius: 10px;
#                 border-left: 4px solid #f093fb;
#                 box-shadow: 0 2px 8px rgba(0,0,0,0.05);
#             ">
#                 <div style="display: flex; align-items: center; gap: 10px; margin-bottom: 8px;">
#                     <span style="font-size: 1.5em;">💡</span>
#                     <strong style="color: #333; font-size: 1.1em;">Project Mentoring</strong>
#                 </div>
#                 <div style="color: #666; font-size: 0.95em; line-height: 1.4;">
#                     Expert project guidance
#                 </div>
#             </div>
#
#             <div style="
#                 background: white;
#                 padding: 15px;
#                 border-radius: 10px;
#                 border-left: 4px solid #f5576c;
#                 box-shadow: 0 2px 8px rgba(0,0,0,0.05);
#             ">
#                 <div style="display: flex; align-items: center; gap: 10px; margin-bottom: 8px;">
#                     <span style="font-size: 1.5em;">🚀</span>
#                     <strong style="color: #333; font-size: 1.1em;">Skill Development</strong>
#                 </div>
#                 <div style="color: #666; font-size: 0.95em; line-height: 1.4;">
#                     Build in-demand skills
#                 </div>
#             </div>
#
#             <div style="
#                 background: white;
#                 padding: 15px;
#                 border-radius: 10px;
#                 border-left: 4px solid #4facfe;
#                 box-shadow: 0 2px 8px rgba(0,0,0,0.05);
#             ">
#                 <div style="display: flex; align-items: center; gap: 10px; margin-bottom: 8px;">
#                     <span style="font-size: 1.5em;">🔍</span>
#                     <strong style="color: #333; font-size: 1.1em;">Industry Research</strong>
#                 </div>
#                 <div style="color: #666; font-size: 0.95em; line-height: 1.4;">
#                     Stay current with industry
#                 </div>
#             </div>
#
#             <div style="
#                 background: white;
#                 padding: 15px;
#                 border-radius: 10px;
#                 border-left: 4px solid #43e97b;
#                 box-shadow: 0 2px 8px rgba(0,0,0,0.05);
#             ">
#                 <div style="display: flex; align-items: center; gap: 10px; margin-bottom: 8px;">
#                     <span style="font-size: 1.5em;">📊</span>
#                     <strong style="color: #333; font-size: 1.1em;">Portfolio Building</strong>
#                 </div>
#                 <div style="color: #666; font-size: 0.95em; line-height: 1.4;">
#                     Showcase your abilities
#                 </div>
#             </div>
#
#             <div style="
#                 background: white;
#                 padding: 15px;
#                 border-radius: 10px;
#                 border-left: 4px solid #ff9a9e;
#                 box-shadow: 0 2px 8px rgba(0,0,0,0.05);
#             ">
#                 <div style="display: flex; align-items: center; gap: 10px; margin-bottom: 8px;">
#                     <span style="font-size: 1.5em;">🎓</span>
#                     <strong style="color: #333; font-size: 1.1em;">Learning Resources</strong>
#                 </div>
#                 <div style="color: #666; font-size: 0.95em; line-height: 1.4;">
#                     Discover top learning materials
#                 </div>
#             </div>
#
#             <div style="
#                 background: white;
#                 padding: 15px;
#                 border-radius: 10px;
#                 border-left: 4px solid #a8edea;
#                 box-shadow: 0 2px 8px rgba(0,0,0,0.05);
#             ">
#                 <div style="display: flex; align-items: center; gap: 10px; margin-bottom: 8px;">
#                     <span style="font-size: 1.5em;">💼</span>
#                     <strong style="color: #333; font-size: 1.1em;">Interview Preparation</strong>
#                 </div>
#                 <div style="color: #666; font-size: 0.95em; line-height: 1.4;">
#                     Ace your job interviews
#                 </div>
#             </div>
#
#         </div>
#     </div>
#     <div style="
#         background: linear-gradient(135deg, #a8edea 0%, #fed6e3 100%);
#         padding: 20px;
#         border-radius: 15px;
#         margin: 30px 0 10px 0;
#         text-align: center;
#         box-shadow: 0 6px 20px rgba(168, 237, 234, 0.3);
#         border: 1px solid rgba(255,255,255,0.5);
#     ">
#         <div style="display: flex; align-items: center; justify-content: center; gap: 15px; flex-wrap: wrap;">
#             <div style="display: flex; align-items: center; gap: 8px;">
#                 <span style="background: #667eea; color: white; border-radius: 50%;
#                            width: 25px; height: 25px; display: flex; align-items: center;
#                            justify-content: center; font-size: 0.8em;">💡</span>
#                 <span style="color: #666; font-weight: 500;">Quick Start</span>
#             </div>
#             <div style="display: flex; align-items: center; gap: 8px;">
#                 <span style="background: #764ba2; color: white; border-radius: 50%;
#                            width: 25px; height: 25px; display: flex; align-items: center;
#                            justify-content: center; font-size: 0.8em;">🎯</span>
#                 <span style="color: #666; font-weight: 500;">Focused Topics</span>
#             </div>
#             <div style="display: flex; align-items: center; gap: 8px;">
#                 <span style="background: #f5576c; color: white; border-radius: 50%;
#                            width: 25px; height: 25px; display: flex; align-items: center;
#                            justify-content: center; font-size: 0.8em;">🚀</span>
#                 <span style="color: #666; font-weight: 500;">Instant Results</span>
#             </div>
#         </div>
#         <div style="margin-top: 15px; color: #666; font-size: 0.95em;">
#             <strong>Pro Tip:</strong> Use these quick actions as starting points, then ask follow-up questions for personalized advice!
#         </div>
#     </div>

# %% [markdown]
# # **ADVANCED CONTROL PANEL: Web Interface Configuration**
#
# Setting up the professional development interface:
# • **Proxy Server Setup**: Secure tunnel for web interface access
# • **Kernel Integration**: Seamless Jupyter environment connection
# • **Visual Guidance**: Step-by-step launch instructions
# • **One-Click Access**: Instant portal to advanced agent controls
#
# *Preparing the command center for advanced agent management...*

# %%
# Cell 8: Enhanced ADK Web UI setup function
def get_adk_proxy_url():
    PROXY_HOST = "https://kkb-production.jupyter-proxy.kaggle.net"
    ADK_PORT = "8000"

    servers = list(list_running_servers())
    if not servers:
        raise Exception("No running Jupyter servers found.")

    baseURL = servers[0]["base_url"]

    try:
        path_parts = baseURL.split("/")
        kernel = path_parts[2]
        token = path_parts[3]
    except IndexError:
        raise Exception(f"Could not parse kernel/token from base URL: {baseURL}")

    url_prefix = f"/k/{kernel}/{token}/proxy/proxy/{ADK_PORT}"
    url = f"{PROXY_HOST}{url_prefix}"

    styled_html = f"""
    <div style="padding: 20px; border: 2px solid #FF6B35; border-radius: 10px; background: linear-gradient(135deg, #fff8e1 0%, #ffecb3 100%); margin: 20px 0;">
        <div style="font-family: 'Arial', sans-serif; margin-bottom: 15px; color: #333;">
            <h3 style="color: #FF6B35; margin: 0 0 10px 0;">🌐 ADK Web Interface</h3>
            <div style="background: #fff3e0; padding: 15px; border-radius: 6px; border-left: 4px solid #FF6B35;">
                <strong>⚠️ Action Required:</strong> Follow these steps to launch the ADK Web UI
                <ol style="margin: 10px 0 0 0; padding-left: 20px;">
                    <li style="margin-bottom: 8px;"><strong>Run the next cell</strong> to start the ADK web server</li>
                    <li style="margin-bottom: 8px;">Wait for the cell to show "Running" status</li>
                    <li style="margin-bottom: 8px;"><strong>Return here and click the button below</strong> to open the interface</li>
                </ol>
            </div>
        </div>
        <a href='{url}' target='_blank' style="
            display: inline-block; background: linear-gradient(135deg, #FF6B35 0%, #F7931E 100%); 
            color: white; padding: 12px 25px; text-decoration: none; border-radius: 25px; 
            font-family: sans-serif; font-weight: 600; font-size: 14px;
            box-shadow: 0 4px 15px rgba(255, 107, 53, 0.3); transition: all 0.3s ease;">
            🚀 Launch ADK Web UI (After starting server) ↗
        </a>
    </div>
    """

    display(HTML(styled_html))
    return url_prefix

# Display the ADK interface info
url_prefix = get_adk_proxy_url()
# Out:
#     <div style="padding: 20px; border: 2px solid #FF6B35; border-radius: 10px; background: linear-gradient(135deg, #fff8e1 0%, #ffecb3 100%); margin: 20px 0;">
#         <div style="font-family: 'Arial', sans-serif; margin-bottom: 15px; color: #333;">
#             <h3 style="color: #FF6B35; margin: 0 0 10px 0;">🌐 ADK Web Interface</h3>
#             <div style="background: #fff3e0; padding: 15px; border-radius: 6px; border-left: 4px solid #FF6B35;">
#                 <strong>⚠️ Action Required:</strong> Follow these steps to launch the ADK Web UI
#                 <ol style="margin: 10px 0 0 0; padding-left: 20px;">
#                     <li style="margin-bottom: 8px;"><strong>Run the next cell</strong> to start the ADK web server</li>
#                     <li style="margin-bottom: 8px;">Wait for the cell to show "Running" status</li>
#                     <li style="margin-bottom: 8px;"><strong>Return here and click the button below</strong> to open the interface</li>
#                 </ol>
#             </div>
#         </div>
#         <a href='https://kkb-production.jupyter-proxy.kaggle.net/k/281267884/eyJhbGciOiJkaXIiLCJlbmMiOiJBMTI4Q0JDLUhTMjU2IiwidHlwIjoiSldUIn0..UnzAblQEO7HHxx_8MUj-eA.z68K7LqGV5yoR-SEmjF2Cw92vjrKxt-Pun4HgO73tcUKr4DcHiciJuXaJ4WnVEaCrkRqPi6xtd4Ts0Lop1I4nJ9zNr158D6axbo5xqNTgQOYlCja7otfvxcGQhbdWAtMbPrzEklhi1NQPMPjxNMclW6FTzQrVxgfTVM7dxQ2MdS2P7UXoFZf1SmX3a2pUN2tyWGRgsGMbmh5fcnHVmnsUSugWGf_2yZ_3WeShnn-DZk2_4amzwSgl5RFxREbOwK-.y6QpMmSc3BTor8SUltN3TQ/proxy/proxy/8000' target='_blank' style="
#             display: inline-block; background: linear-gradient(135deg, #FF6B35 0%, #F7931E 100%);
#             color: white; padding: 12px 25px; text-decoration: none; border-radius: 25px;
#             font-family: sans-serif; font-weight: 600; font-size: 14px;
#             box-shadow: 0 4px 15px rgba(255, 107, 53, 0.3); transition: all 0.3s ease;">
#             🚀 Launch ADK Web UI (After starting server) ↗
#         </a>
#     </div>

# %% [markdown]
# # **SERVER ACTIVATION: Web Interface Launch**
#
# Initiating the ADK web server with:
# • **Background Service**: Continuous server operation
# • **Real-time Status**: Live monitoring of server health
# • **Automatic Configuration**: Optimized settings for Kaggle environment
# • **Persistent Connection**: Stable interface access
#
# *Launching the web control panel for advanced agent operations...*

# %%
# Cell 9: Start the ADK web server
print("🚀 Starting ADK Web Server...")
print("This cell will remain running while the server is active.")
print("Once you see 'Running' status, return to the previous cell and click the launch button.")

# !adk web --url_prefix {url_prefix}
# Out:
# 🚀 Starting ADK Web Server...
# This cell will remain running while the server is active.
# Once you see 'Running' status, return to the previous cell and click the launch button.
# /usr/local/lib/python3.11/dist-packages/google/adk/cli/fast_api.py:130: UserWarning: [EXPERIMENTAL] InMemoryCredentialService: This feature is experimental and may change or be removed in future versions without notice. It may introduce breaking changes at any time.
#   credential_service = InMemoryCredentialService()
# /usr/local/lib/python3.11/dist-packages/google/adk/auth/credential_service/in_memory_credential_service.py:33: UserWarning: [EXPERIMENTAL] BaseCredentialService: This feature is experimental and may change or be removed in future versions without notice. It may introduce breaking changes at any time.
#   super().__init__()
# INFO:     Started server process [107]
# INFO:     Waiting for application startup.
#
# +-----------------------------------------------------------------------------+
# | ADK Web Server started                                                      |
# |                                                                             |
# | For local testing, access at http://127.0.0.1:8000.                         |
# +-----------------------------------------------------------------------------+
#
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)
# INFO:     35.191.59.95:0 - "GET / HTTP/1.1" 307 Temporary Redirect
# INFO:     35.191.59.92:0 - "GET /dev-ui/ HTTP/1.1" 200 OK
# INFO:     35.191.59.95:0 - "GET /dev-ui/main-OS2OH2S3.js HTTP/1.1" 200 OK
# INFO:     35.191.59.94:0 - "GET /dev-ui/chunk-2WH2EVR6.js HTTP/1.1" 200 OK
# INFO:     35.191.59.93:0 - "GET /dev-ui/polyfills-B6TNHZQ6.js HTTP/1.1" 200 OK
# INFO:     35.191.59.92:0 - "GET /dev-ui/styles-EVMPSV3U.css HTTP/1.1" 200 OK
# INFO:     35.191.59.94:0 - "GET /dev-ui/assets/config/runtime-config.json HTTP/1.1" 200 OK
# INFO:     35.191.59.93:0 - "GET /dev-ui/adk_favicon.svg HTTP/1.1" 200 OK
# INFO:     35.191.59.95:0 - "GET /list-apps?relative_path=./ HTTP/1.1" 200 OK
# INFO:     35.191.59.92:0 - "GET /dev-ui/assets/ADK-512-color.svg HTTP/1.1" 200 OK
# INFO:google_adk.google.adk.cli.adk_web_server:New session created: cc145702-ff89-460d-89fd-41d44be9a053
# INFO:     35.191.59.94:0 - "POST /apps/sample-agent/users/user/sessions HTTP/1.1" 200 OK
# INFO:     35.191.59.93:0 - "GET /builder/app/sample-agent?ts=1763931060297 HTTP/1.1" 200 OK
# INFO:     35.191.59.95:0 - "GET /apps/sample-agent/eval_sets HTTP/1.1" 200 OK
# INFO:     35.191.59.92:0 - "GET /apps/sample-agent/eval_results HTTP/1.1" 200 OK
# INFO:     35.191.59.94:0 - "GET /apps/sample-agent/users/user/sessions/cc145702-ff89-460d-89fd-41d44be9a053 HTTP/1.1" 200 OK
# INFO:     35.191.59.93:0 - "GET /apps/sample-agent/users/user/sessions HTTP/1.1" 200 OK
# INFO:     35.191.59.95:0 - "GET /debug/trace/session/cc145702-ff89-460d-89fd-41d44be9a053 HTTP/1.1" 200 OK
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'alias' attribute with value 'appName' was provided to the `Field()` function, which has no effect in the context it was used. 'alias' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'validation_alias' attribute with value 'appName' was provided to the `Field()` function, which has no effect in the context it was used. 'validation_alias' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'serialization_alias' attribute with value 'appName' was provided to the `Field()` function, which has no effect in the context it was used. 'serialization_alias' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'alias' attribute with value 'userId' was provided to the `Field()` function, which has no effect in the context it was used. 'alias' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'validation_alias' attribute with value 'userId' was provided to the `Field()` function, which has no effect in the context it was used. 'validation_alias' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'serialization_alias' attribute with value 'userId' was provided to the `Field()` function, which has no effect in the context it was used. 'serialization_alias' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'alias' attribute with value 'sessionId' was provided to the `Field()` function, which has no effect in the context it was used. 'alias' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'validation_alias' attribute with value 'sessionId' was provided to the `Field()` function, which has no effect in the context it was used. 'validation_alias' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'serialization_alias' attribute with value 'sessionId' was provided to the `Field()` function, which has no effect in the context it was used. 'serialization_alias' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'alias' attribute with value 'newMessage' was provided to the `Field()` function, which has no effect in the context it was used. 'alias' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'validation_alias' attribute with value 'newMessage' was provided to the `Field()` function, which has no effect in the context it was used. 'validation_alias' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'serialization_alias' attribute with value 'newMessage' was provided to the `Field()` function, which has no effect in the context it was used. 'serialization_alias' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'alias' attribute with value 'streaming' was provided to the `Field()` function, which has no effect in the context it was used. 'alias' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'validation_alias' attribute with value 'streaming' was provided to the `Field()` function, which has no effect in the context it was used. 'validation_alias' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'serialization_alias' attribute with value 'streaming' was provided to the `Field()` function, which has no effect in the context it was used. 'serialization_alias' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'alias' attribute with value 'stateDelta' was provided to the `Field()` function, which has no effect in the context it was used. 'alias' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'validation_alias' attribute with value 'stateDelta' was provided to the `Field()` function, which has no effect in the context it was used. 'validation_alias' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'serialization_alias' attribute with value 'stateDelta' was provided to the `Field()` function, which has no effect in the context it was used. 'serialization_alias' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'alias' attribute with value 'invocationId' was provided to the `Field()` function, which has no effect in the context it was used. 'alias' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'validation_alias' attribute with value 'invocationId' was provided to the `Field()` function, which has no effect in the context it was used. 'validation_alias' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'serialization_alias' attribute with value 'invocationId' was provided to the `Field()` function, which has no effect in the context it was used. 'serialization_alias' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# INFO:     35.191.59.92:0 - "POST /run_sse HTTP/1.1" 200 OK
# INFO:google_adk.google.adk.cli.utils.agent_loader:Found root_agent in sample-agent.agent
# INFO:google_adk.google.adk.models.google_llm:Sending out request, model: gemini-2.5-flash-lite, backend: GoogleLLMVariant.GEMINI_API, stream: False
# INFO:google_adk.google.adk.models.google_llm:Response received from the model.
# INFO:     35.191.59.94:0 - "GET /debug/trace/session/cc145702-ff89-460d-89fd-41d44be9a053 HTTP/1.1" 200 OK
# INFO:     35.191.59.93:0 - "GET /apps/sample-agent/users/user/sessions/cc145702-ff89-460d-89fd-41d44be9a053 HTTP/1.1" 200 OK
# INFO:     35.191.59.95:0 - "GET /debug/trace/session/cc145702-ff89-460d-89fd-41d44be9a053 HTTP/1.1" 200 OK
# INFO:     35.191.59.92:0 - "POST /run_sse HTTP/1.1" 200 OK
# INFO:google_adk.google.adk.models.google_llm:Sending out request, model: gemini-2.5-flash-lite, backend: GoogleLLMVariant.GEMINI_API, stream: False
# INFO:google_adk.google.adk.models.google_llm:Response received from the model.
# INFO:     35.191.59.95:0 - "GET /debug/trace/session/cc145702-ff89-460d-89fd-41d44be9a053 HTTP/1.1" 200 OK
# INFO:     35.191.59.93:0 - "GET /apps/sample-agent/users/user/sessions/cc145702-ff89-460d-89fd-41d44be9a053 HTTP/1.1" 200 OK
# INFO:     35.191.59.94:0 - "GET /debug/trace/session/cc145702-ff89-460d-89fd-41d44be9a053 HTTP/1.1" 200 OK

# %% [markdown]
#  # **DEVELOPER SANDBOX: Sample Agent Creation**
#
# Building a test environment for experimentation:
# • **Template Agent**: Pre-configured starter agent
# • **Model Optimization**: Gemini 2.5 Flash Lite configuration
# • **API Integration**: Secure key authentication
# • **Development Foundation**: Base for custom agent builds
#
# *Setting up your playground for AI agent development and testing...*

# %%
# Cell 10: Create a sample agent with enhanced styling
def create_sample_agent():
    display(HTML("""
    <div style="padding: 15px; border: 2px solid #17a2b8; border-radius: 8px; background-color: #e8f4f8; margin: 20px 0;">
        <div style="font-family: sans-serif; color: #333;">
            <strong style="color: #138496;">🛠️ Creating Sample Agent...</strong>
            <p style="margin: 10px 0 0 0; color: #555;">
                This will create a sample agent configuration for advanced testing.
            </p>
        </div>
    </div>
    """))
    
    try:
        # !adk create sample-agent --model gemini-2.5-flash-lite --api_key $GOOGLE_API_KEY
        display(HTML("""
        <div style="padding: 15px; border: 2px solid #28a745; border-radius: 8px; background-color: #f0f9f0; margin: 20px 0;">
            <div style="font-family: sans-serif; color: #333;">
                <strong style="color: #2E7D32;">✅ Sample Agent Created Successfully!</strong>
                <p style="margin: 10px 0 0 0; color: #555;">
                    You can now explore advanced agent configurations.
                </p>
            </div>
        </div>
        """))
    except Exception as e:
        display(HTML(f"""
        <div style="padding: 15px; border: 2px solid #dc3545; border-radius: 8px; background-color: #f8d7da; margin: 20px 0;">
            <div style="font-family: sans-serif; color: #333;">
                <strong style="color: #721c24;">❌ Error Creating Sample Agent</strong>
                <p style="margin: 10px 0 0 0; color: #555;">{e}</p>
            </div>
        </div>
        """))

create_sample_agent()
# Out:
#     <div style="padding: 15px; border: 2px solid #17a2b8; border-radius: 8px; background-color: #e8f4f8; margin: 20px 0;">
#         <div style="font-family: sans-serif; color: #333;">
#             <strong style="color: #138496;">🛠️ Creating Sample Agent...</strong>
#             <p style="margin: 10px 0 0 0; color: #555;">
#                 This will create a sample agent configuration for advanced testing.
#             </p>
#         </div>
#     </div>
# Agent created in /kaggle/working/sample-agent:
# - .env
# - __init__.py
# - agent.py
#         <div style="padding: 15px; border: 2px solid #28a745; border-radius: 8px; background-color: #f0f9f0; margin: 20px 0;">
#             <div style="font-family: sans-serif; color: #333;">
#                 <strong style="color: #2E7D32;">✅ Sample Agent Created Successfully!</strong>
#                 <p style="margin: 10px 0 0 0; color: #555;">
#                     You can now explore advanced agent configurations.
#                 </p>
#             </div>
#         </div>

# %% [markdown]
# # **INTELLIGENCE VERIFICATION: Agent Capability Testing**
#
# Validating Athena's research prowess through:
# • **Diverse Query Suite**: Multiple research scenarios
# • **Real-time Search**: Live information retrieval testing
# • **Response Quality**: Comprehensive answer evaluation
# • **Error Handling**: Robust performance under various conditions
#
# *Demonstrating Athena's powerful research capabilities in action...*

# %%
# Cell 11: Test the Athena Agent with sample queries
async def test_athena_agent():
    test_queries = [
        "What is Google's Agent Development Kit and what are its main features?",
        "How can I improve my machine learning model's performance?",
        "What are the latest advancements in natural language processing?"
    ]
    
    display(HTML("""
    <div style="padding: 15px; border: 2px solid #6f42c1; border-radius: 8px; background-color: #eae4f2; margin: 20px 0;">
        <div style="font-family: sans-serif; color: #333;">
            <strong style="color: #6f42c1;">🧪 Testing Athena Agent...</strong>
            <p style="margin: 10px 0 0 0; color: #555;">
                Running sample queries to demonstrate capabilities.
            </p>
        </div>
    </div>
    """))
    
    for i, query in enumerate(test_queries, 1):
        display(HTML(f"""
        <div style="background: #007bff; color: white; padding: 10px 15px; margin: 10px 0; 
                    border-radius: 8px; border-left: 4px solid #0056b3;">
            <strong>Test Query {i}:</strong> {query}
        </div>
        """))
        
        try:
            response = await runner.run_debug(query)
            display(HTML(f"""
            <div style="background: #28a745; color: white; padding: 15px; margin: 10px 0; 
                        border-radius: 8px; border-left: 4px solid #1e7e34;">
                <strong>🏛️ Athena Response:</strong><br>{response}
            </div>
            """))
        except Exception as e:
            display(HTML(f"""
            <div style="background: #dc3545; color: white; padding: 15px; margin: 10px 0; 
                        border-radius: 8px; border-left: 4px solid #c82333;">
                <strong>❌ Error:</strong> {str(e)}
            </div>
            """))

# Run the test
await test_athena_agent()
# Out:
#     <div style="padding: 15px; border: 2px solid #6f42c1; border-radius: 8px; background-color: #eae4f2; margin: 20px 0;">
#         <div style="font-family: sans-serif; color: #333;">
#             <strong style="color: #6f42c1;">🧪 Testing Athena Agent...</strong>
#             <p style="margin: 10px 0 0 0; color: #555;">
#                 Running sample queries to demonstrate capabilities.
#             </p>
#         </div>
#     </div>
#         <div style="background: #007bff; color: white; padding: 10px 15px; margin: 10px 0;
#                     border-radius: 8px; border-left: 4px solid #0056b3;">
#             <strong>Test Query 1:</strong> What is Google's Agent Development Kit and what are its main features?
#         </div>
#  ### Created new session: debug_session_id
#
# User > What is Google's Agent Development Kit and what are its main features?
# Athena_Research_Assistant > Google's Agent Development Kit (ADK) is an open-source, flexible, and modular framework designed to simplify the development, deployment, and orchestration of AI agents and multi-agent systems. It aims to make agent development more akin to traditional software development, providing developers with a structured approach to creating sophisticated AI solutions. While optimized for Google's Gemini models and ecosystem, ADK is model-agnostic and deployment-agnostic, making it compatible with various tools and frameworks.
#
# The main features of Google's Agent Development Kit include:
#
# *   **Multi-Agent Architecture:** Enables the creation of modular and scalable applications by composing multiple specialized agents that work together hierarchically to achieve complex goals.
# *   **Flexible Orchestration:** Allows developers to define structured workflows using agents like Sequential, Parallel, and Loop, or to leverage LLM-driven dynamic routing for adaptive behavior.
# *   **Rich Tool Ecosystem:** Agents can be equipped with diverse capabilities through pre-built tools (e.g., Search, Code Execution), custom functions, integration with third-party libraries (like LangChain and LlamaIndex), or by using other agents as tools.
# *   **Model Flexibility:** Supports Gemini models directly, models from Vertex AI Model Garden, and can integrate with models from other providers through LiteLLM.
# *   **Native Streaming Support:** Offers built-in capabilities for bidirectional streaming of text, audio, and video, enabling more natural and real-time human-like interactions.
# *   **Integrated Developer Tooling:** Provides tools like a command-line interface (CLI) and a visual web UI for running agents, debugging, inspecting execution steps, and visualizing agent definitions.
# *   **Built-in Evaluation:** Includes mechanisms for systematically assessing agent performance.
# *   **Artifact Management:** Features a built-in system for storing and versioning data, capable of handling structured data, documents, audio, and video, supporting multimodal AI.
# *   **Interoperability:** Built on Google's Agent Protocol, allowing agents from different companies to interact safely.
#
# ADK is designed to tackle the core challenges of multi-agent development, offering precise control over agent behavior and orchestration, and aims to empower developers to build production-ready agentic applications.
#             <div style="background: #28a745; color: white; padding: 15px; margin: 10px 0;
#                         border-radius: 8px; border-left: 4px solid #1e7e34;">
#                 <strong>🏛️ Athena Response:</strong><br>[Event(model_version='gemini-2.5-flash-lite', content=Content(
#   parts=[
#     Part(
#       text="""Google's Agent Development Kit (ADK) is an open-source, flexible, and modular framework designed to simplify the development, deployment, and orchestration of AI agents and multi-agent systems. It aims to make agent development more akin to traditional software development, providing developers with a structured approach to creating sophisticated AI solutions. While optimized for Google's Gemini models and ecosystem, ADK is model-agnostic and deployment-agnostic, making it compatible with various tools and frameworks.
#
# The main features of Google's Agent Development Kit include:
#
# *   **Multi-Agent Architecture:** Enables the creation of modular and scalable applications by composing multiple specialized agents that work together hierarchically to achieve complex goals.
# *   **Flexible Orchestration:** Allows developers to define structured workflows using agents like Sequential, Parallel, and Loop, or to leverage LLM-driven dynamic routing for adaptive behavior.
# *   **Rich Tool Ecosystem:** Agents can be equipped with diverse capabilities through pre-built tools (e.g., Search, Code Execution), custom functions, integration with third-party libraries (like LangChain and LlamaIndex), or by using other agents as tools.
# *   **Model Flexibility:** Supports Gemini models directly, models from Vertex AI Model Garden, and can integrate with models from other providers through LiteLLM.
# *   **Native Streaming Support:** Offers built-in capabilities for bidirectional streaming of text, audio, and video, enabling more natural and real-time human-like interactions.
# *   **Integrated Developer Tooling:** Provides tools like a command-line interface (CLI) and a visual web UI for running agents, debugging, inspecting execution steps, and visualizing agent definitions.
# *   **Built-in Evaluation:** Includes mechanisms for systematically assessing agent performance.
# *   **Artifact Management:** Features a built-in system for storing and versioning data, capable of handling structured data, documents, audio, and video, supporting multimodal AI.
# *   **Interoperability:** Built on Google's Agent Protocol, allowing agents from different companies to interact safely.
#
# ADK is designed to tackle the core challenges of multi-agent development, offering precise control over agent behavior and orchestration, and aims to empower developers to build production-ready agentic applications."""
#     ),
#   ],
#   role='model'
# ), grounding_metadata=GroundingMetadata(
#   grounding_chunks=[
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         title='github.io',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQFKxPVWhRY1TzeTFPA_n24pp8KUZn99hlK8M6bRsc833GI0ZO24U7OmP06xOeMVJrC2bu4icbA1oxRf1JUNGLuQO_pBdOy-WOrc1jfsln5Pdy3jPdguux4HoiaOSQ=='
#       )
#     ),
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         title='siddharthbharath.com',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQFR6XQe2KDvieiLAH-frf7c19-0z-HLCwbpaxJ8F3RWgj46fMzeBYyeNN9s7Mu5VH-8xk6g94Ak0dTQGKleWWmbxzcT91nL9LarHFy3DCSDqHLOLynKxYImRuNzxWIu92iCLuVBssXL_B03i_SZxyXkTkjPd9Ut-Puu-AUIHvPXwRJkA1E1GoTkKpeeDUymHKRH9yY='
#       )
#     ),
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         title='googleblog.com',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQEVCEVbMeRwZjbAjeF7LWN5bzz2hrf5QjYEEvVjhi5ykzpVbeiSOOV5jdCyFBiEKdw95alauy4zY7MdnNe6c5yxHdstJEKSwc_yc-Ylhh_Qcj8Ymm9-tB15rKXtbjwqtIv1tfM-tNONGoQDGGBueTz4L6HmTH-wXDc5IScfNNmK-O3_yQl067iEBRB8FoyXuXGUgIJdxYzVV7gFTdI='
#       )
#     ),
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         title='google.com',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQEit_ghoxDf9Gs0EIfQ_JXHP3GvTjS20R0RwQE7IkSezN5Nuj4SKT-qB2FaB0Gb50kW4NQ-c7_mY6LhdeUO26s0XYJwj-QNa4fTCstxG0TqPmlXBlRhkjkE7mUQgFC86QakJEGuYBDX8gQhuuuD0hAqniklrWLEArFbFA39SUqLb0qWk1c='
#       )
#     ),
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         title='dev.to',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQFcbf1zjANQpM2NFfr503_lk2yqyyQrHrC8aI_BDEa5dyHhDapvRbKxbad_8wgsAsE4Ehpb8MDYi6wkCe1kmaZSAyNE8MClENevHyL_5RyMoStwhOMQG_3XZXcc8HI7XX8aHruEyM3HIsk6HJf_PNAVYtK8Z1zKj-zlhXWzrMlH576NGYGwkYr5ZTwASrwnXEOa9sMnOigx2ASROHKgwLeP0Oa-Jo0iBFsfcH4FbYg='
#       )
#     ),
#     <... 4 more items ...>,
#   ],
#   grounding_supports=[
#     GroundingSupport(
#       grounding_chunk_indices=[
#         0,
#         1,
#         2,
#         3,
#         4,
#         <... 2 more items ...>,
#       ],
#       segment=Segment(
#         end_index=193,
#         text="Google's Agent Development Kit (ADK) is an open-source, flexible, and modular framework designed to simplify the development, deployment, and orchestration of AI agents and multi-agent systems."
#       )
#     ),
#     GroundingSupport(
#       grounding_chunk_indices=[
#         2,
#         4,
#         5,
#       ],
#       segment=Segment(
#         end_index=362,
#         start_index=194,
#         text='It aims to make agent development more akin to traditional software development, providing developers with a structured approach to creating sophisticated AI solutions.'
#       )
#     ),
#     GroundingSupport(
#       grounding_chunk_indices=[
#         0,
#         3,
#         4,
#         6,
#       ],
#       segment=Segment(
#         end_index=523,
#         start_index=363,
#         text="While optimized for Google's Gemini models and ecosystem, ADK is model-agnostic and deployment-agnostic, making it compatible with various tools and frameworks."
#       )
#     ),
#     GroundingSupport(
#       grounding_chunk_indices=[
#         0,
#         1,
#         7,
#         8,
#       ],
#       segment=Segment(
#         end_index=779,
#         start_index=587,
#         text='*   **Multi-Agent Architecture:** Enables the creation of modular and scalable applications by composing multiple specialized agents that work together hierarchically to achieve complex goals.'
#       )
#     ),
#     GroundingSupport(
#       grounding_chunk_indices=[
#         0,
#         1,
#         7,
#       ],
#       segment=Segment(
#         end_index=975,
#         start_index=780,
#         text='*   **Flexible Orchestration:** Allows developers to define structured workflows using agents like Sequential, Parallel, and Loop, or to leverage LLM-driven dynamic routing for adaptive behavior.'
#       )
#     ),
#     <... 8 more items ...>,
#   ],
#   search_entry_point=SearchEntryPoint(
#     rendered_content="""<style>
# .container {
#   align-items: center;
#   border-radius: 8px;
#   display: flex;
#   font-family: Google Sans, Roboto, sans-serif;
#   font-size: 14px;
#   line-height: 20px;
#   padding: 8px 12px;
# }
# .chip {
#   display: inline-block;
#   border: solid 1px;
#   border-radius: 16px;
#   min-width: 14px;
#   padding: 5px 16px;
#   text-align: center;
#   user-select: none;
#   margin: 0 8px;
#   -webkit-tap-highlight-color: transparent;
# }
# .carousel {
#   overflow: auto;
#   scrollbar-width: none;
#   white-space: nowrap;
#   margin-right: -12px;
# }
# .headline {
#   display: flex;
#   margin-right: 4px;
# }
# .gradient-container {
#   position: relative;
# }
# .gradient {
#   position: absolute;
#   transform: translate(3px, -9px);
#   height: 36px;
#   width: 9px;
# }
# @media (prefers-color-scheme: light) {
#   .container {
#     background-color: #fafafa;
#     box-shadow: 0 0 0 1px #0000000f;
#   }
#   .headline-label {
#     color: #1f1f1f;
#   }
#   .chip {
#     background-color: #ffffff;
#     border-color: #d2d2d2;
#     color: #5e5e5e;
#     text-decoration: none;
#   }
#   .chip:hover {
#     background-color: #f2f2f2;
#   }
#   .chip:focus {
#     background-color: #f2f2f2;
#   }
#   .chip:active {
#     background-color: #d8d8d8;
#     border-color: #b6b6b6;
#   }
#   .logo-dark {
#     display: none;
#   }
#   .gradient {
#     backgr
#         <div style="background: #007bff; color: white; padding: 10px 15px; margin: 10px 0;
#                     border-radius: 8px; border-left: 4px solid #0056b3;">
#             <strong>Test Query 2:</strong> How can I improve my machine learning model's performance?
#         </div>
#  ### Continue session: debug_session_id
#
# User > How can I improve my machine learning model's performance?
# Athena_Research_Assistant > Improving a machine learning model's performance is an iterative process that involves various techniques across data preparation, model selection, training, and evaluation. Here are key strategies:
#
# ### Data Quality and Preprocessing
#
# *   **Clean Your Data:** This is foundational. Address missing values through imputation (mean, median, mode, or more advanced methods), remove duplicate entries, and correct inconsistencies. Inaccurate or incomplete data will lead to poor model performance.
# *   **Handle Outliers:** Outliers can skew results and negatively impact model evaluation metrics. Identify and decide how to handle them, whether by removal, transformation, or using algorithms robust to outliers.
# *   **Feature Engineering and Selection:** Create new features from existing ones that might be more informative for the model. Select the most relevant features and remove redundant or irrelevant ones. Too few features can make a model less robust, while too many can lead to overfitting and the "curse of dimensionality."
# *   **Data Augmentation:** If you have limited training data, data augmentation can create new samples by modifying existing ones, effectively increasing the dataset size and diversity.
# *   **Normalization and Standardization:** Rescale features to a common range. Normalization typically scales data to a range between 0 and 1, while standardization centers data around the mean with a unit standard deviation. This is crucial for algorithms sensitive to feature scales.
#
# ### Model Training and Selection
#
# *   **Choose the Right Algorithm:** Select an algorithm that is well-suited to your specific data and task. For instance, linear models might not perform well on highly non-linear data.
# *   **Hyperparameter Tuning:** Most models have hyperparameters that control their learning process. Optimizing these parameters (e.g., learning rate, regularization strength, number of layers) can significantly boost performance. Techniques like grid search, random search, or Bayesian optimization can be used.
# *   **Regularization:** To prevent overfitting (where the model learns the training data too well, including noise, and performs poorly on unseen data), apply regularization techniques like L1 or L2 regularization. These add a penalty term to the loss function, discouraging overly complex models.
# *   **Address Overfitting and Underfitting:**
#     *   **Overfitting:** If your model is overfitting, consider using more diverse training data, reducing model complexity, or applying regularization.
#     *   **Underfitting:** If your model is underfitting (too simple to capture the data's patterns), you might need to increase model complexity (e.g., add more features, use a more complex algorithm) or train for longer.
#
# ### Evaluation and Iteration
#
# *   **Use Appropriate Evaluation Metrics:** Ensure you are using metrics that accurately reflect the problem's goals. For imbalanced datasets, accuracy might be misleading; metrics like F1-score, precision, and recall are often more informative.
# *   **Cross-Validation:** Employ techniques like k-fold cross-validation to get a more reliable estimate of your model's performance on unseen data and to help detect overfitting.
# *   **Ensemble Methods:** Combine predictions from multiple models. Ensembles often yield better performance and generalization ability than individual models by reducing variance and bias. Common methods include bagging, boosting, and stacking.
# *   **Monitor for Data Drift:** In production, data distributions can change over time (data drift). Regularly monitor incoming data against training data and retrain your model if significant drift is detected.
# *   **Failure Analysis:** Understand why your model makes incorrect predictions. Analyze misclassified instances to identify patterns or weaknesses in your model or data.
#
# Improving model performance is an ongoing cycle. It requires careful attention to data quality, thoughtful model selection and tuning, rigorous evaluation, and continuous monitoring.
#             <div style="background: #28a745; color: white; padding: 15px; margin: 10px 0;
#                         border-radius: 8px; border-left: 4px solid #1e7e34;">
#                 <strong>🏛️ Athena Response:</strong><br>[Event(model_version='gemini-2.5-flash-lite', content=Content(
#   parts=[
#     Part(
#       text="""Improving a machine learning model's performance is an iterative process that involves various techniques across data preparation, model selection, training, and evaluation. Here are key strategies:
#
# ### Data Quality and Preprocessing
#
# *   **Clean Your Data:** This is foundational. Address missing values through imputation (mean, median, mode, or more advanced methods), remove duplicate entries, and correct inconsistencies. Inaccurate or incomplete data will lead to poor model performance.
# *   **Handle Outliers:** Outliers can skew results and negatively impact model evaluation metrics. Identify and decide how to handle them, whether by removal, transformation, or using algorithms robust to outliers.
# *   **Feature Engineering and Selection:** Create new features from existing ones that might be more informative for the model. Select the most relevant features and remove redundant or irrelevant ones. Too few features can make a model less robust, while too many can lead to overfitting and the "curse of dimensionality."
# *   **Data Augmentation:** If you have limited training data, data augmentation can create new samples by modifying existing ones, effectively increasing the dataset size and diversity.
# *   **Normalization and Standardization:** Rescale features to a common range. Normalization typically scales data to a range between 0 and 1, while standardization centers data around the mean with a unit standard deviation. This is crucial for algorithms sensitive to feature scales.
#
# ### Model Training and Selection
#
# *   **Choose the Right Algorithm:** Select an algorithm that is well-suited to your specific data and task. For instance, linear models might not perform well on highly non-linear data.
# *   **Hyperparameter Tuning:** Most models have hyperparameters that control their learning process. Optimizing these parameters (e.g., learning rate, regularization strength, number of layers) can significantly boost performance. Techniques like grid search, random search, or Bayesian optimization can be used.
# *   **Regularization:** To prevent overfitting (where the model learns the training data too well, including noise, and performs poorly on unseen data), apply regularization techniques like L1 or L2 regularization. These add a penalty term to the loss function, discouraging overly complex models.
# *   **Address Overfitting and Underfitting:**
#     *   **Overfitting:** If your model is overfitting, consider using more diverse training data, reducing model complexity, or applying regularization.
#     *   **Underfitting:** If your model is underfitting (too simple to capture the data's patterns), you might need to increase model complexity (e.g., add more features, use a more complex algorithm) or train for longer.
#
# ### Evaluation and Iteration
#
# *   **Use Appropriate Evaluation Metrics:** Ensure you are using metrics that accurately reflect the problem's goals. For imbalanced datasets, accuracy might be misleading; metrics like F1-score, precision, and recall are often more informative.
# *   **Cross-Validation:** Employ techniques like k-fold cross-validation to get a more reliable estimate of your model's performance on unseen data and to help detect overfitting.
# *   **Ensemble Methods:** Combine predictions from multiple models. Ensembles often yield better performance and generalization ability than individual models by reducing variance and bias. Common methods include bagging, boosting, and stacking.
# *   **Monitor for Data Drift:** In production, data distributions can change over time (data drift). Regularly monitor incoming data against training data and retrain your model if significant drift is detected.
# *   **Failure Analysis:** Understand why your model makes incorrect predictions. Analyze misclassified instances to identify patterns or weaknesses in your model or data.
#
# Improving model performance is an ongoing cycle. It requires careful attention to data quality, thoughtful model selection and tuning, rigorous evaluation, and continuous monitoring."""
#     ),
#   ],
#   role='model'
# ), grounding_metadata=GroundingMetadata(
#   grounding_chunks=[
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         title='neptune.ai',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQHCesIbiO3TRbM0xUBaGU7XeABkB9upH_lqzHfPw8iop_SdebSjV0lO8kEmIFBCl_LuNStndURnIXR3b7Z7g5RAvbfHsdWy8VmqAUrq2dKFO-QiXdCgGaklwEORfARbkt0uPgf0a1Mxd6fVNrpehzII'
#       )
#     ),
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         title='medium.com',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQGdV1GNAXfWPXUEmuDBPuEZaKwddGXdvT_8OJcawcL-jFk_zXtXfKbAqjUjJgMuillpSCb_vPoEe0IBER8-knrmse8vTSN_773cZmTKhVovvP51l73lnuDfEg8Wan-H-CWFt1yGQHwzWPARUIOkHLsgRAcsYhJhS8I4Jh4pO2nqdnJ5W5pFuZqdKQUOnzVX2hfWBecKHE92NDs='
#       )
#     ),
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         title='geeksforgeeks.org',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQHAqyyK2ljB-LsfvVpFxr8NL8CwQ4OGf3vtFIPDUCzdwXIlmPgcOPJD_ZUdkfG8VNI2Tmwja-lGYEeuiZDeN0H9mqXoJVO91KiP3DgpX5bot4ucAIw7080ns1hj4SazvrrrPvUNqkntesotMo2K3GedVdNeZcf7y0USE62gqRBC'
#       )
#     ),
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         title='medium.com',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQE4800A0KV0LcmWjB9q4Kk10vtO665uADOEg8y-iDOFGY_aSoSnlotXZ103xVx_ccAG9JMUAnZaJzVHJGiIfGrehUQun-BxsmrgQfeBRGMrynMLj5EAEl5KYL4egCC4xhO50rYby94XMLDhtLra43RmlYsUwFfgxMlF6QWij6mOLnjW-KdubLl7n8j2rnYq6DWU8GuoCn2hI-hnNZwW5LbUAA=='
#       )
#     ),
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         title='kaggle.com',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQFh5Wmzft2ztk0WNfGrQlA7GcErtdwJs5jMgKD2dvar7Mo4dj3WZu0j8tO1lR8mvoXU24qMiZipcJVOgCnPTtQc2UWH3WJiY_U_DT8PmzgP0KApHTT0n6KuaT7Gg8r5ujcndUfxG30K9AsNogKTS1ko5Wc-ASSmEXdm'
#       )
#     ),
#     <... 3 more items ...>,
#   ],
#   grounding_supports=[
#     GroundingSupport(
#       grounding_chunk_indices=[
#         0,
#         1,
#         2,
#       ],
#       segment=Segment(
#         end_index=494,
#         start_index=428,
#         text='Inaccurate or incomplete data will lead to poor model performance.'
#       )
#     ),
#     GroundingSupport(
#       grounding_chunk_indices=[
#         0,
#       ],
#       segment=Segment(
#         end_index=709,
#         start_index=594,
#         text='Identify and decide how to handle them, whether by removal, transformation, or using algorithms robust to outliers.'
#       )
#     ),
#     GroundingSupport(
#       grounding_chunk_indices=[
#         0,
#         1,
#       ],
#       segment=Segment(
#         end_index=1033,
#         start_index=913,
#         text='Too few features can make a model less robust, while too many can lead to overfitting and the "curse of dimensionality."'
#       )
#     ),
#     GroundingSupport(
#       grounding_chunk_indices=[
#         0,
#       ],
#       segment=Segment(
#         end_index=1219,
#         start_index=1034,
#         text='*   **Data Augmentation:** If you have limited training data, data augmentation can create new samples by modifying existing ones, effectively increasing the dataset size and diversity.'
#       )
#     ),
#     GroundingSupport(
#       grounding_chunk_indices=[
#         3,
#       ],
#       segment=Segment(
#         end_index=1505,
#         start_index=1446,
#         text='This is crucial for algorithms sensitive to feature scales.'
#       )
#     ),
#     <... 10 more items ...>,
#   ],
#   search_entry_point=SearchEntryPoint(
#     rendered_content="""<style>
# .container {
#   align-items: center;
#   border-radius: 8px;
#   display: flex;
#   font-family: Google Sans, Roboto, sans-serif;
#   font-size: 14p
#         <div style="background: #007bff; color: white; padding: 10px 15px; margin: 10px 0;
#                     border-radius: 8px; border-left: 4px solid #0056b3;">
#             <strong>Test Query 3:</strong> What are the latest advancements in natural language processing?
#         </div>
#  ### Continue session: debug_session_id
#
# User > What are the latest advancements in natural language processing?
# Athena_Research_Assistant > **Recent advancements in Natural Language Processing (NLP) are rapidly transforming how machines understand and interact with human language, leading to more sophisticated applications and a deeper integration of AI into our daily lives.** Key developments span across several areas:
#
# ### Transformer Models and Large Language Models (LLMs)
#
# *   **Dominance of Transformer Architecture:** Models like BERT (Bidirectional Encoder Representations from Transformers) and GPT (Generative Pre-trained Transformer) continue to be at the forefront, revolutionizing NLP. Their self-attention mechanisms allow them to process text more effectively by understanding relationships between words regardless of their position.
# *   **Advancements in LLMs:** Large Language Models, such as GPT-4, PaLM, and LLaMA, with billions of parameters, are setting new benchmarks. They excel at generating human-like text, answering complex questions, and translating languages with high fluency and accuracy. These models have become foundational for over 50% of NLP applications.
# *   **Efficient Transformers:** To address the computational cost and memory consumption of transformers, researchers are developing efficient attention mechanisms (e.g., linear attention, sparse attention) to handle longer input sequences and make large-scale NLP more affordable and sustainable.
#
# ### Conversational AI and Virtual Assistants
#
# *   **Sophisticated Chatbots:** Conversational AI and chatbots have seen significant improvements due to advancements in deep learning and reinforcement learning. They are now capable of more contextually relevant, personalized, and human-like interactions.
# *   **Evolving Virtual Assistants:** Virtual assistants are becoming integral components that enhance accessibility and information retrieval across various domains, from enterprise solutions to personal devices.
#
# ### Multimodal NLP
#
# *   **Integrating Language with Other Modalities:** Multimodal NLP focuses on understanding and generating language across text, images, audio, and video. This integration allows for a deeper understanding of content and context, enabling applications like image captioning, video summarization, and voice-enabled search. Models like CLIP and DALL-E demonstrate the ability to process and generate content across visual and textual data.
#
# ### Zero-Shot and Few-Shot Learning
#
# *   **Generalizing to Unseen Tasks:** Zero-shot learning allows NLP models to generalize to tasks or concepts they haven't been explicitly trained on by leveraging semantic embeddings and transfer learning. Few-shot learning enables models to learn from just a few examples, which is crucial in scenarios with scarce labeled data. This capability is particularly impactful for multilingual NLP, allowing models to understand languages they haven't been explicitly trained in.
#
# ### Ethical and Responsible AI in NLP
#
# *   **Addressing Bias and Fairness:** As NLP becomes more pervasive, there's a growing emphasis on ethical AI practices. Research focuses on mitigating bias, ensuring fairness, and maintaining privacy in NLP applications, especially in sensitive domains.
# *   **Explainable AI (XAI):** Efforts are underway to make NLP models more transparent and interpretable, allowing users to understand how models arrive at their decisions. Techniques like attention mechanisms and saliency maps are used for this purpose.
#
# ### Other Key Advancements
#
# *   **Multilingual NLP:** Models are increasingly capable of handling multiple languages without requiring retraining for each, improving global access to AI tools.
# *   **NLP in Specialized Domains:** NLP is making significant strides in sectors like healthcare for analyzing medical records and improving patient care, and in finance for fraud detection and market trend prediction.
# *   **Autonomous Language Agents:** AI systems are being developed to plan, take actions, and complete multi-step tasks with minimal supervision, moving NLP from simply understanding to actively performing tasks.
# *   **Named Entity Recognition (NER):** NER systems are becoming more prominent for classifying and annotating diverse data parameters in unstructured text, enhancing data extraction workflows.
# *   **Text Summarization:** Advanced NLP models are adept at summarizing extensive texts concisely while retaining key information, boosting efficiency and productivity.
# *   **Semantic Search:** NLP is making search more intuitive by analyzing search intent, delivering more relevant results across various applications.
#
# These advancements collectively point towards an NLP landscape that is more powerful, versatile, and integrated into our lives, while also acknowledging the growing importance of ethical considerations and computational efficiency.
#             <div style="background: #28a745; color: white; padding: 15px; margin: 10px 0;
#                         border-radius: 8px; border-left: 4px solid #1e7e34;">
#                 <strong>🏛️ Athena Response:</strong><br>[Event(model_version='gemini-2.5-flash-lite', content=Content(
#   parts=[
#     Part(
#       text="""**Recent advancements in Natural Language Processing (NLP) are rapidly transforming how machines understand and interact with human language, leading to more sophisticated applications and a deeper integration of AI into our daily lives.** Key developments span across several areas:
#
# ### Transformer Models and Large Language Models (LLMs)
#
# *   **Dominance of Transformer Architecture:** Models like BERT (Bidirectional Encoder Representations from Transformers) and GPT (Generative Pre-trained Transformer) continue to be at the forefront, revolutionizing NLP. Their self-attention mechanisms allow them to process text more effectively by understanding relationships between words regardless of their position.
# *   **Advancements in LLMs:** Large Language Models, such as GPT-4, PaLM, and LLaMA, with billions of parameters, are setting new benchmarks. They excel at generating human-like text, answering complex questions, and translating languages with high fluency and accuracy. These models have become foundational for over 50% of NLP applications.
# *   **Efficient Transformers:** To address the computational cost and memory consumption of transformers, researchers are developing efficient attention mechanisms (e.g., linear attention, sparse attention) to handle longer input sequences and make large-scale NLP more affordable and sustainable.
#
# ### Conversational AI and Virtual Assistants
#
# *   **Sophisticated Chatbots:** Conversational AI and chatbots have seen significant improvements due to advancements in deep learning and reinforcement learning. They are now capable of more contextually relevant, personalized, and human-like interactions.
# *   **Evolving Virtual Assistants:** Virtual assistants are becoming integral components that enhance accessibility and information retrieval across various domains, from enterprise solutions to personal devices.
#
# ### Multimodal NLP
#
# *   **Integrating Language with Other Modalities:** Multimodal NLP focuses on understanding and generating language across text, images, audio, and video. This integration allows for a deeper understanding of content and context, enabling applications like image captioning, video summarization, and voice-enabled search. Models like CLIP and DALL-E demonstrate the ability to process and generate content across visual and textual data.
#
# ### Zero-Shot and Few-Shot Learning
#
# *   **Generalizing to Unseen Tasks:** Zero-shot learning allows NLP models to generalize to tasks or concepts they haven't been explicitly trained on by leveraging semantic embeddings and transfer learning. Few-shot learning enables models to learn from just a few examples, which is crucial in scenarios with scarce labeled data. This capability is particularly impactful for multilingual NLP, allowing models to understand languages they haven't been explicitly trained in.
#
# ### Ethical and Responsible AI in NLP
#
# *   **Addressing Bias and Fairness:** As NLP becomes more pervasive, there's a growing emphasis on ethical AI practices. Research focuses on mitigating bias, ensuring fairness, and maintaining privacy in NLP applications, especially in sensitive domains.
# *   **Explainable AI (XAI):** Efforts are underway to make NLP models more transparent and interpretable, allowing users to understand how models arrive at their decisions. Techniques like attention mechanisms and saliency maps are used for this purpose.
#
# ### Other Key Advancements
#
# *   **Multilingual NLP:** Models are increasingly capable of handling multiple languages without requiring retraining for each, improving global access to AI tools.
# *   **NLP in Specialized Domains:** NLP is making significant strides in sectors like healthcare for analyzing medical records and improving patient care, and in finance for fraud detection and market trend prediction.
# *   **Autonomous Language Agents:** AI systems are being developed to plan, take actions, and complete multi-step tasks with minimal supervision, moving NLP from simply understanding to actively performing tasks.
# *   **Named Entity Recognition (NER):** NER systems are becoming more prominent for classifying and annotating diverse data parameters in unstructured text, enhancing data extraction workflows.
# *   **Text Summarization:** Advanced NLP models are adept at summarizing extensive texts concisely while retaining key information, boosting efficiency and productivity.
# *   **Semantic Search:** NLP is making search more intuitive by analyzing search intent, delivering more relevant results across various applications.
#
# These advancements collectively point towards an NLP landscape that is more powerful, versatile, and integrated into our lives, while also acknowledging the growing importance of ethical considerations and computational efficiency."""
#     ),
#   ],
#   role='model'
# ), grounding_metadata=GroundingMetadata(
#   grounding_chunks=[
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         title='medium.com',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQHYXvX6qeWUirnOkWpGdFaQM6SdvoUg2nKcN8LBgA9q2R2VnwZqtHltGjpoDT1QhJ2e5-NSabEWZpJUWgGLNWlL2oTvhPaefABXFuIr_mhceeS5TXvO1JGMFIME0Q2RV5qtfjO2yX-8oLGQes74pilrreaNbP3pVTNBhJII9JuAD0GhyZY4CAfehBdds0y8HOnU6zh8Kpcwn7pvy06Y4eaVyHEaiAZS1TmDM4F2UFvj-iqoMUIHOr1r'
#       )
#     ),
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         title='reddit.com',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQGUn_6KgcfDolXn73UirED2SqEJfJBoOjSr-_RdL7VlnlEznoiKOAG3-F1ISZqNPZ8U-Fl_lYMsnMMQZWIfuC280cvRsTxAWaEXc52RNWTA5JGdst-q4M-ZqZ1SS_GAyhGuXEkRtSnkejxSVVqLA1uz5_KpdlBrP7tPBTCuNm7PvJWOpDaFfwPQalfnJRNbFy5vLkljnDF9GdCkTOcwZQ=='
#       )
#     ),
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         title='artsmart.ai',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQE6yt_qwwhEkHbXlh9cc1RpYJdPnZyBMum7JSh6xkKvq35KJR2rpL182-Bt122KSkkcnE8ewS-Hd2c8PMkhIQPXOwfVJdJ0NV-BPVJDwC7-ghYaOFVVz-_qFzPoLCG1GK83uvOaae6uwCPDF5hCxyRQpyunAI9rBC3plh4r48K7cdSJ-xM='
#       )
#     ),
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         title='kdnuggets.com',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQFtPG3Sfe_VlfKfLbVwwsaPsHPdTLYXCUlSUE8s3qxLuePzFuHYTFQ8ADVYMLZRAoXYzGAqDmIZak7gieshVKKobovDnIEcwTYMCA3jPiISUiEyObsNhHc-T1p8KN79hWZP6_26y6kCYL3v4BGzqe-s8PcofoGr1BAZKwnJID9SaIfD7h79xuTCAtk2fIMbmOiwutM='
#       )
#     ),
#     GroundingChunk(
#       web=GroundingChunkWeb(
#         title='predikly.com',
#         uri='https://vertexaisearch.cloud.google.com/grounding-api-redirect/AUZIYQFks4aoGiaWiemNooBYivqkzTvP2Iw5-9WoGOZRSIxx5gkZ72i4C0C9JCqlbsAkjhMUcTj2WB84zquw8XvDfuMJTmOdoCOJ6wxQmDpL_mUelR1-1L1gxDGV_SssiK0Oo0o6kAFT'
#       )
#     ),
#     <... 5 more items ...>,
#   ],
#   grounding_supports=[
#     GroundingSupport(
#       grounding_chunk_indices=[
#         0,
#         1,
#       ],
#       segment=Segment(
#         end_index=712,
#         start_index=563,
#         text='Their self-attention mechanisms allow them to process text more effectively by understanding relationships between words regardless of their position'
#       )
#     ),
#     GroundingSupport(
#       grounding_chunk_indices=[
#         0,
#         2,
#       ],
#       segment=Segment(
#         end_index=983,
#         start_index=856,
#         text='They excel at generating human-like text, answering complex questions, and translating languages with high fluency and accuracy'
#       )
#     ),
#     GroundingSupport(
#       grounding_chunk_indices=[
#         2,
#       ],
#       segment=Segment(
#         end_index=1055,
#         start_index=985,
#         text='These models have become foundational for over 50% of NLP applications'
#       )
#     ),
#     Gr

# %% [markdown]
# # **MISSION ACCOMPLISHED: Athena Research Assistant Ready!**
#
# Your intelligent research companion is now fully operational with:
#
# 🚀 **Core Intelligence**
# • Advanced Gemini 2.5 Flash Lite model
# • Real-time Google Search integration
# • Sophisticated reasoning capabilities
#
# 💫 **User Experience**
# • Beautiful interactive chat interface
# • Quick-action research shortcuts
# • Professional web control panel
#
# ⚡ **Performance Features**
# • Robust error recovery system
# • High-speed response processing
# • Continuous conversation context
#
# *Athena is now ready to be your personal research expert!*

# %%
# Cell 12: Display completion summary
completion_html = """
<div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); 
            padding: 30px; border-radius: 15px; color: white; text-align: center;
            margin: 20px 0; box-shadow: 0 8px 25px rgba(0,0,0,0.15);">
    <h1 style="margin: 0 0 15px 0; font-family: 'Arial', sans-serif;">🎉 Athena Agent Setup Complete!</h1>
    
    <div style="background: rgba(255,255,255,0.1); padding: 20px; border-radius: 10px; margin: 20px 0;">
        <h3 style="margin-top: 0;">✅ What's Ready:</h3>
        <div style="display: grid; grid-template-columns: repeat(auto-fit, minmax(250px, 1fr)); gap: 15px; text-align: left;">
            <div>🤖 <strong>Intelligent Agent</strong> - Powered by Gemini 2.5 Flash Lite</div>
            <div>🔍 <strong>Web Search</strong> - Real-time information retrieval</div>
            <div>💬 <strong>Chat Interface</strong> - Beautiful interactive UI</div>
            <div>🌐 <strong>Web UI</strong> - Advanced ADK interface</div>
            <div>🚀 <strong>Quick Actions</strong> - Common research queries</div>
            <div>⚡ <strong>Error Handling</strong> - Robust retry mechanisms</div>
        </div>
    </div>
    
    <div style="background: rgba(255,255,255,0.1); padding: 15px; border-radius: 8px;">
        <h4 style="margin: 0 0 10px 0;">Next Steps:</h4>
        <p style="margin: 0; opacity: 0.9;">
            Use the chat interface above to start researching, or launch the ADK Web UI for advanced features!
        </p>
    </div>
</div>
"""

display(HTML(completion_html))
# Out:
# <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%);
#             padding: 30px; border-radius: 15px; color: white; text-align: center;
#             margin: 20px 0; box-shadow: 0 8px 25px rgba(0,0,0,0.15);">
#     <h1 style="margin: 0 0 15px 0; font-family: 'Arial', sans-serif;">🎉 Athena Agent Setup Complete!</h1>
#
#     <div style="background: rgba(255,255,255,0.1); padding: 20px; border-radius: 10px; margin: 20px 0;">
#         <h3 style="margin-top: 0;">✅ What's Ready:</h3>
#         <div style="display: grid; grid-template-columns: repeat(auto-fit, minmax(250px, 1fr)); gap: 15px; text-align: left;">
#             <div>🤖 <strong>Intelligent Agent</strong> - Powered by Gemini 2.5 Flash Lite</div>
#             <div>🔍 <strong>Web Search</strong> - Real-time information retrieval</div>
#             <div>💬 <strong>Chat Interface</strong> - Beautiful interactive UI</div>
#             <div>🌐 <strong>Web UI</strong> - Advanced ADK interface</div>
#             <div>🚀 <strong>Quick Actions</strong> - Common research queries</div>
#             <div>⚡ <strong>Error Handling</strong> - Robust retry mechanisms</div>
#         </div>
#     </div>
#
#     <div style="background: rgba(255,255,255,0.1); padding: 15px; border-radius: 8px;">
#         <h4 style="margin: 0 0 10px 0;">Next Steps:</h4>
#         <p style="margin: 0; opacity: 0.9;">
#             Use the chat interface above to start researching, or launch the ADK Web UI for advanced features!
#         </p>
#     </div>
# </div>
